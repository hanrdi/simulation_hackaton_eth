# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
#from Common import NeuralNet, MultiVariatePoly
import time
torch.manual_seed(128)

# %% [markdown]
# Consider the porous 2D incompressible steady-state Stokes equation:
# $\newcommand{\Reynolds}{\text{Re}}\renewcommand{\div}{\text{div}}$
# $$
#  -\nabla \hat{p} + \div(\frac{2}{\Reynolds} \epsilon(\hat{u}))
#  -\frac{1}{\Reynolds} \left(\frac{5L^2}{2H_t^2} + \hat{\alpha}(\rho)\right) \hat{u} = 0
# $$
# $$
# \div(\hat{u})= 0
# $$
#
# with constant inflow and boundary conditions
# $$
# u_b(0,y) = \text{const} u_{in}
# $$
#
# $$
# u_b(x,0)=u_b(x,1)=0,
# $$
#
# We want to obtain an approximate solution of $u : [0,1]\times[0,1] \mapsto \mathbb{R}^2$ with physics informed neural networks (PINNs).
#
# To do so, we approximate the underlying solution with a feedforward dense neural network with tunable parameters $\theta$:
#
# $$
# u_\theta(x,y) \approx u(x,y)
# $$
# Define the following residuals:
#
#    - Interior residual given by,
#
#    $$r_{int,0,\theta}(x, y):= -\nabla \hat{p} + \div(\frac{2}{\Reynolds} \epsilon(\hat{u}))
#  -\frac{1}{\Reynolds} \left(\frac{5L^2}{2H_t^2} + \hat{\alpha}(\rho)\right) \hat{u}$$
#    $$r_{int,1,\theta}(x, y):= \div(\hat{u})$$
#
#    - inflow boundary residual given by,
#
#         $$r_{ib,\theta}(x,y):= u_{\theta}(x,y)- u_in$$
#
#    - outside boundary residual given by,
#
#         $$r_{ob,\theta}(x,0):= u_{\theta}(x,0), r_{ob, \theta}(x,1) := u_{\theta}(x,1) \quad \forall x \in [-1,1].$$
#
# and compute the corresponding loss functions:
#
# $$
# L_{int,0}(\theta) = \int_{[0,1]\times[0,1]}r_{int,0,\theta}^2(x, y) dxdy, \quad
# L_{int,1}(\theta) = \int_{[0,1]\times[0,1]}r_{int,1,\theta}^2(x, y) dxdy, \quad
# L_{ib}(\theta) = \int_{[0,1]}r_{ib,\theta}^2(0,y) dy, \quad
# L_{ob}(\theta) = \int_{[0,1]}r_{ob,\theta}^2(x,0) dx + \int_{[0,1]}r_{ob,\theta}^2(x,1) dx
# $$
#
# The loss functions include integrals that can be approximated by suitable quadrature rule. We use quasi Monte-Carlo and accordingly define the following training sets
#
# $$
# S_{int} =\{z_n\}, \quad 1 \leq n \leq N_{int},\quad z_n = (x,y)_n \in D_T,
# $$
#
# $$
# S_{ib} =\{y_n, u_b(0,y_n) \}, \quad1 \leq n \leq N_{ib}, y_n \in [0,1],
# $$
#
# $$
# S_{ob, 0}=\{x_n, u_0(x_n,0)\}\quad  1 \leq n \leq N_{ob}, x_n \in [0,1].
# $$
#
# $$
# S_{ob, 1}=\{x_n, u_0(x_n,1)\}\quad  1 \leq n \leq N_{ob}, x_n \in [0,1].
# $$
#
#
# with the training inputs points corresponding to low-discrepancy Sobol sequences.
#
# $$
# L_{int,0}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,1,\theta}^2(z_n) , \quad
# L_{int,1}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,1,\theta}^2(z_n) , \quad
# L_{ib}(\theta) = \frac{1}{N_{ib}}\sum_{i=1}^{N_{ib}}r_{sb,\theta}^2(y_n,0)\quad
# L_{ob}(\theta) = \frac{1}{N_{ob}}\sum_{i=1}^{N_{ob}}r_{ob,\theta}^2(x_n,0) +\frac{1}{N_{ob}}\sum_{i=1}^{N_{ob}}r_{ob,\theta}^2(x_n,1)
# $$
#
# and solve the following minimization problem
#
# $$
# \theta^\ast = argmin_{\theta} \Big(L_{int}(\theta) + \lambda_u L_u(\theta)\Big)
# $$
#
# with
#
# $$
# L_{int} = L_{int,0} + L_{int,1}, \quad
# L_u = L_{ib}(\theta) + L_{ob}(\theta)
# $$

# %%
class NeuralNet(nn.Module):

    def __init__(self, input_dimension, output_dimension, n_hidden_layers, neurons, regularization_param, regularization_exp, retrain_seed):
        super(NeuralNet, self).__init__()
        # Number of input dimensions n
        self.input_dimension = input_dimension
        # Number of output dimensions m
        self.output_dimension = output_dimension
        # Number of neurons per layer
        self.neurons = neurons
        # Number of hidden layers
        self.n_hidden_layers = n_hidden_layers
        # Activation function
        self.activation = nn.Tanh()
        self.regularization_param = regularization_param
        # Regularization exponent
        self.regularization_exp = regularization_exp
        # Random seed for weight initialization

        self.input_layer = nn.Linear(self.input_dimension, self.neurons)
        self.hidden_layers = nn.ModuleList([nn.Linear(self.neurons, self.neurons) for _ in range(n_hidden_layers - 1)])
        self.output_layer = nn.Linear(self.neurons, self.output_dimension)
        self.retrain_seed = retrain_seed
        # Random Seed for weight initialization
        self.init_xavier()

    def forward(self, x):
        # The forward function performs the set of affine and non-linear transformations defining the network
        # (see equation above)
        x = self.activation(self.input_layer(x))
        for k, l in enumerate(self.hidden_layers):
            x = self.activation(l(x))
        return self.output_layer(x)

    def init_xavier(self):
        torch.manual_seed(self.retrain_seed)

        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                torch.nn.init.xavier_uniform_(m.weight, gain=g)
                # torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)

    def regularization(self):
        reg_loss = 0
        for name, param in self.named_parameters():
            if 'weight' in name:
                reg_loss = reg_loss + torch.norm(param, self.regularization_exp)
        return self.regularization_param * reg_loss


def fit(model, training_set, num_epochs, optimizer, p, verbose=True):
    history = list()

    # Loop over epochs
    for epoch in range(num_epochs):
        if verbose: print("################################ ", epoch, " ################################")

        running_loss = list([0])

        # Loop over batches
        for j, (x_train_, u_train_) in enumerate(training_set):
            def closure():
                # zero the parameter gradients
                optimizer.zero_grad()
                # forward + backward + optimize
                u_pred_ = model(x_train_)
                # Item 1. below
                loss = torch.mean((u_pred_.reshape(-1, ) - u_train_.reshape(-1, )) ** p) + model.regularization()
                # Item 2. below
                loss.backward()
                # Compute average training loss over batches for the current epoch
                running_loss[0] += loss.item()
                return loss

            # Item 3. below
            optimizer.step(closure=closure)

        if verbose: print('Loss: ', (running_loss[0] / len(training_set)))
        history.append(running_loss[0])

    return history

# %%
class Pinns:
    def __init__(self, n_int_, n_ib_, n_ob_):
        self.n_int = n_int_
        self.n_ib = n_ob_
        self.n_ob = n_ib_

        # Extrema of the solution domain (x,y) in [0,1]x[0,1]
        self.domain_extrema = torch.tensor([[0, 1],[0, 1]])

        # Number of space dimensions
        self.space_dimensions = 2

        # Parameter to balance role of data and PDE
        self.lambda_u = 10
        
        self.T_inlet = 293.15  # K

        self.channel_thickness = 380e-6  # m
        self.Ht = 0.5 * self.channel_thickness

        self.substrate_thickness = 150e-6  # m
        self.Hs = 0.5 * self.substrate_thickness

        self.conductivity_fluid = 0.598
        self.conductivity_substrate = 149
        self.viscosity_fluid = 1.004e-3
        self.capacity_fluid = 4180
        self.density_fluid = 998

        self.applied_pressure = 100000 * 5.0 / 4.0  # kg m^-1 s^-2
        self.L = 0.001  # m
        self.U = np.sqrt(self.applied_pressure / self.density_fluid)  # m/s


        self.nu = self.viscosity_fluid / self.density_fluid
        self.rho = self.load_rho()

        self.Re = self.L * self.U / self.nu
        #Prandtl_number = fd.Constant(capacity_fluid * viscosity_fluid / conductivity_fluid)
        self.nondim_Ht = self.Ht / self.L
        self.nondim_Hs = self.Hs / self.L
        
        self.qk = 1 #this change in each optimization steps
        self.alpha_f = 0
        self.alpha_s = 5*self.L**2/(2*self.Ht**2)

        # F Dense NN to approximate the solution of the underlying equation
        self.approximate_solution = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=3,
                                              n_hidden_layers=3,
                                              neurons=20,
                                              regularization_param=0.,
                                              regularization_exp=2.,
                                              retrain_seed=42)
        '''self.approximate_solution = MultiVariatePoly(self.domain_extrema.shape[0], 3)'''

        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(dimension=self.domain_extrema.shape[0])
        

        # Training sets S_ib, S_ob, S_int as torch dataloader
#         self.training_set_ib, self.training_set_ob, self.training_set_int, self.training_set_pb = self.assemble_datasets()
        self.training_set_ib, self.training_set_ob, self.training_set_int  = self.assemble_datasets()

    def load_rho(self):
        file_path = "/home/team/CAMLab-DLSCTutorials/"
        #file_path = "C:\\Users\\bonvi\\Documents\\simulation_hack\\simulation_hackaton_eth-rafael\\simulation_hackaton_eth-rafael\\formatted_data0\\"
        file = file_path + 'results-0.h5_rhof.out'
        rho = np.zeros((100,100))
        rho[:, 40:60] = np.full(rho[:, 40:60].shape, 1)
        return rho
        #return np.loadtxt(file)

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0]) + self.domain_extrema[:, 0]

    # Initial condition to solve the inflow boundary condition
    def initial_condition(self, x):
        return np.array([1,0])


    ################################################################################################
    # Function returning the input-output tensor required to assemble the training set S_ib corresponding to the vertical boundary
    def add_inflow_boundary_points(self):
        #y0 = self.domain_extrema[0,1]
        input_ib = self.convert(self.soboleng.draw(self.n_ib))
        input_ib[:, 0] = torch.full(input_ib[:, 0].shape, 0)
#         output_ib = self.initial_condition(input_ib[:, 1]).reshape(-1, 1)  # reshape to [64, 1]
        output_ib = torch.clone(input_ib)
        output_ib[:,0] = torch.full(output_ib[:,0].shape,1)
        output_ib[:,1] = torch.full(output_ib[:,1].shape,0)
    
#         output_ib = self.initial_condition(input_ib[:, 1]).reshape(-1, 1)
        #print("Shape of input_ib[:, 1]:", input_ib[:, 1].shape)
        #print("Shape of output_ib:", output_ib.shape)


        return input_ib, output_ib

    # Function returning the input-output tensor required to assemble the training set S_ob corresponding to the horizontal boundary
    def add_horizontal_boundary_points(self):

        input_ob = self.convert(self.soboleng.draw(self.n_ob))

        input_ob_0 = torch.clone(input_ob)
        input_ob_0[:, 1] = torch.full(input_ob_0[:, 1].shape, 0)

        input_ob_L = torch.clone(input_ob)
        input_ob_L[:, 1] = torch.full(input_ob_L[:, 1].shape, 1)

        output_ob_0 = torch.clone(input_ob)
        output_ob_0[:, 0] = torch.full(output_ob_0[:, 0].shape, 0)
        output_ob_0[:, 1] = torch.full(output_ob_0[:, 1].shape, 0)
        output_ob_L = torch.clone(input_ob)
        output_ob_L[:, 0] = torch.full(output_ob_L[:, 0].shape, 0)
        output_ob_L[:, 1] = torch.full(output_ob_L[:, 1].shape, 0)

        return torch.cat([input_ob_0, input_ob_L], 0), torch.cat([output_ob_0, output_ob_L], 0)
    
    # Function returning the input-output tensor required to assemble the training set S_ib corresponding to the vertical boundary
    def add_exit_boundary_points(self):
        input_eb = self.convert(self.soboleng.draw(self.n_eb))
        input_eb[:, 0] = torch.full(input_eb[:, 0].shape, 1)
#         output_ib = self.initial_condition(input_ib[:, 1]).reshape(-1, 1)  # reshape to [64, 1]
        output_eb = torch.clone(input_ib)
        output_eb[:,0] = torch.full(output_eb[:,0].shape,0)
    
#         output_ib = self.initial_condition(input_ib[:, 1]).reshape(-1, 1)
        #print("Shape of input_ib[:, 1]:", input_ib[:, 1].shape)
        #print("Shape of output_ib:", output_ib.shape)


        return input_eb, output_eb
        
    #  Function returning the input-output tensor required to assemble the training set S_int corresponding to the interior domain where the PDE is enforced
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int
    

    # Function returning the training sets S_ib, S_ob, S_int as dataloader
    def assemble_datasets(self):
        input_ib, output_ib = self.add_inflow_boundary_points()  # S_ib
        input_ob, output_ob = self.add_horizontal_boundary_points()   # S_ob
        input_int, output_int = self.add_interior_points()         # S_int
#         input_pb, output_pb =self.add_p_points()

#         training_set_ib = DataLoader(torch.utils.data.TensorDataset(input_ib, output_ib), shuffle=False)
#         training_set_ob = DataLoader(torch.utils.data.TensorDataset(input_ob, output_ob), shuffle=False)
#         training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), shuffle=False)
        training_set_ib = DataLoader(torch.utils.data.TensorDataset(input_ib, output_ib), batch_size=self.n_ib, shuffle=False)
        training_set_ob = DataLoader(torch.utils.data.TensorDataset(input_ob, output_ob), batch_size=2*self.n_ob, shuffle=False)
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)
#         training_set_p = DataLoader(torch.utils.data.TensorDataset(input_pb, output_pb), batch_size=self.n_int, shuffle=False)
        return training_set_ib, training_set_ob, training_set_int #, training_set_p

    ################################################################################################
    # Function to compute the terms required in the definition of the INFLOW boundary residual
    def apply_inflow_condition(self, input_ib):
        u_pred_ib = self.approximate_solution(input_ib)#[:,0:2]
        return u_pred_ib

    # Function to compute the terms required in the definition of the HORIZONTAL boundary residual
    def apply_boundary_conditions(self, input_ob):
        u_pred_ob = self.approximate_solution(input_ob)#[:,0:2]

        return u_pred_ob

    def alpha(self,rho):
        return (1-rho)/(1+self.qk*rho)*(self.alpha_s - self.alpha_f)+self.alpha_f
    
    def interpolate_rho(self,input_int):
        input_int = (input_int.detach().numpy() * 100).astype(int)
        rho = np.zeros((input_int.shape[0],1))
        for i in range(input_int.shape[0]):
            x = input_int[i,0]
            y = input_int[i,1]
            rho[i] = self.rho[x,y]
        return torch.Tensor(rho)
        
    def compute_pde_residual(self, input_int):
        rho = self.interpolate_rho(input_int)
        input_int.requires_grad = True # save gradients
        
        u = self.approximate_solution(input_int)[:,0:2]
        p = self.approximate_solution(input_int)[:,2] 

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 + u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        #print(grad_u[0].shape)
        #grad_u = grad_u[0]
        grad_u_x = grad_u[:, 0]
        grad_u_y = grad_u[:, 1]
        #grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 0]
        #grad_u_xx_y = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 1]
        #grad_u_yy = torch.autograd.grad(grad_u_y.sum(), input_int, create_graph=True)[0][:, 1]
        #grad_u_yy_x = torch.autograd.grad(grad_u_y.sum(), input_int, create_graph=True)[0][:, 0]
        grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0]
        grad_u_yy = torch.autograd.grad(grad_u_y.sum(), input_int, create_graph=True)[0]


        grad_p = torch.autograd.grad(p.sum(), input_int, create_graph=True)[0]

        
        nabla_p = grad_p
        #div_term = 2*self.Re*(torch.concat((grad_u_xx + grad_u_yy_x, grad_u_xx_y + grad_u_yy))).reshape(-1,2)
        div_term = 2*self.Re*(torch.concat((torch.sum(grad_u_xx, dim=1),torch.sum(grad_u_yy, dim =1)))).reshape(-1,2)
        drag_term = 1/self.Re * (5 * self.L**2 / (2 * self.Ht**2) + self.alpha(rho)) * u
        
        residual = -nabla_p + div_term - drag_term
        return residual.reshape(-1, )
    
    
    # Function to compute the incompressibility term residuals on the interior
    def compute_incompress_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)[:,0:2]

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 + u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_x = grad_u[:, 0]
        grad_u_y = grad_u[:, 1]
        div_u = grad_u_x + grad_u_y
    
        return div_u.reshape(-1, )

    # Function to compute the total loss (weighted sum of inflow boundary loss, horizontal boundary loss and interior loss)
    def compute_loss(self, inp_train_ib, u_train_ib, inp_train_ob, u_train_ob, inp_train_int, verbose=True):
        u_pred_ib = self.apply_inflow_condition(inp_train_ib)[:,0:2]
        u_pred_ob = self.apply_boundary_conditions(inp_train_ob)[:,0:2]
#         p_pred_ib = self.apply_inflow_condition(inp_train_ib)[:,3]
#         p_pred_pb = self.apply_inflow_condition(inp_train_pb)[:,3]
        #p_pred_ob = self.apply_boundary_condition(inp_train_ob)[:,2:4]
        
#         print("Shape of u_pred_ib", u_pred_ib.shape)
#         print("Shape of u_train_ib:", u_train_ib.shape)
        #print("Shape of u_pred_ob", u_pred_ob.shape)
        #print("Shape of u_train_ob:", u_train_ob.shape)
        


        assert (u_pred_ib.shape[1] == u_train_ib.shape[1])
        assert (u_pred_ob.shape[1] == u_train_ob.shape[1])
        #assert (p_pred_ib.shape[1] == u_train_ib.shape[1])
        #assert (p_pred_ob.shape[1] == u_train_ob.shape[1])

        r_int = self.compute_pde_residual(inp_train_int)
        r_inc = self.compute_incompress_residual(inp_train_int)
        r_ib = u_train_ib - u_pred_ib
        r_ob = u_train_ob - u_pred_ob
#         r_ib_p = u_train_ib - p_pred_ib
#         r_pb = u_train_pb - p_pred_pb
        #r_ob_p = u_train_ob - p_pred_ob

        loss_ib = torch.mean(abs(r_ib) ** 2)
        loss_ob = torch.mean(abs(r_ob) ** 2)
#         loss_ib_p = torch.mean(abs(r_ib_p) ** 2)
#         loss_pb = torch.mean(abs(r_pb) **2)
        #loss_ob_p = torch.mean(abs(r_ob_p) ** 2)
        loss_int = torch.mean(abs(r_int) ** 2)
        loss_inc = torch.mean(abs(r_inc) ** 2)

        
        loss_u =  loss_ib + loss_ob
#         loss_p = loss_ib_p + loss_pb#+ loss_ob_p

        loss = torch.log10(self.lambda_u * (loss_u) + loss_int + loss_inc)
        #loss = loss_u  + loss_p
        if verbose: print("Total loss: ", round(loss.item(), 3), "| PDE Loss: ", round(torch.log10(loss_u).item(), 3), "| Function Loss: ", round(torch.log10(loss_int + loss_inc).item(), 3))

        return loss

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")
            for j, ((inp_train_ib, u_train_ib), (inp_train_ob, u_train_ob), (inp_train_int, u_train_int)) in enumerate(zip(self.training_set_ib, self.training_set_ob, self.training_set_int)):

#             for j, ((inp_train_ib, u_train_ib), (inp_train_ob, u_train_ob), (inp_train_int, u_train_int), (inp_train_pb, u_train_pb)) in enumerate(zip(self.training_set_ib, self.training_set_ob, self.training_set_int, self.training_set_pb)):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_ib, u_train_ib, inp_train_ob, u_train_ob, inp_train_int, verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ################################################################################################
    def plotting(self):
        inputs = self.soboleng.draw(100000)
        #inputs = self.convert(inputs)

        output_ux = self.approximate_solution(inputs)[:,0].reshape(-1, )
        output_uy = self.approximate_solution(inputs)[:,1].reshape(-1, )
        output_p = self.approximate_solution(inputs)[:,2].reshape(-1, )
#         output_py = self.approximate_solution(inputs)[:,3].reshape(-1, )
#         exact_output = self.exact_solution(inputs).reshape(-1, )

        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].tripcolor(inputs[:, 0].detach(), inputs[:, 1].detach(), output_ux.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].tripcolor(inputs[:, 0].detach(), inputs[:, 1].detach(), output_uy.detach(), cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[1].set_title("u_y")
        axs[0].set_title("u_x")

        plt.show()
        
        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].tripcolor(inputs[:, 0].detach(), inputs[:, 1].detach(), output_p.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        axs[0].set_title("p")

        plt.show()

#         err = (torch.mean((output - exact_output) ** 2) / torch.mean(exact_output ** 2)) ** 0.5 * 100
#         print("L2 Relative Error Norm: ", err.item(), "%")

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi x)

n_int = 256
n_sb = 64
n_tb = 64

pinn = Pinns(n_int, n_sb, n_tb)

# %%
# Plot the input training points
input_ib_, output_ib_ = pinn.add_inflow_boundary_points()
input_ob_, output_ob_ = pinn.add_horizontal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()

plt.figure(figsize=(16, 8), dpi=150)
plt.scatter(input_ob_[:, 0].detach().numpy(), input_ob_[:, 1].detach().numpy(), label="Boundary Points")
plt.scatter(input_int_[:, 0].detach().numpy(), input_int_[:, 1].detach().numpy(), label="Interior Points")
plt.scatter(input_ib_[:, 0].detach().numpy(), input_ib_[:, 1].detach().numpy(), label="Initial Points")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
n_epochs = 1
optimizer_LBFGS = optim.LBFGS(pinn.approximate_solution.parameters(),
                              lr=float(0.5),
                              max_iter=50000,
                              max_eval=50000,
                              history_size=150,
                              line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.001))

# %%
hist = pinn.fit(num_epochs=n_epochs,
                optimizer=optimizer_LBFGS,
                verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  10.056 | PDE Loss:  0.078 | Function Loss:  10.056
# Total loss:  9.981 | PDE Loss:  0.012 | Function Loss:  9.981
# Total loss:  9.481 | PDE Loss:  -0.259 | Function Loss:  9.481
# Total loss:  9.269 | PDE Loss:  -0.202 | Function Loss:  9.269
# Total loss:  9.274 | PDE Loss:  0.405 | Function Loss:  9.274
# Total loss:  8.964 | PDE Loss:  0.201 | Function Loss:  8.964
# Total loss:  8.77 | PDE Loss:  -0.204 | Function Loss:  8.77
# Total loss:  8.625 | PDE Loss:  -0.331 | Function Loss:  8.625
# Total loss:  8.176 | PDE Loss:  -0.189 | Function Loss:  8.176
# Total loss:  9.535 | PDE Loss:  0.694 | Function Loss:  9.535
# Total loss:  8.101 | PDE Loss:  0.004 | Function Loss:  8.101
# Total loss:  7.911 | PDE Loss:  -0.046 | Function Loss:  7.911
# Total loss:  7.775 | PDE Loss:  -0.184 | Function Loss:  7.775
# Total loss:  7.623 | PDE Loss:  -0.165 | Function Loss:  7.623
# Total loss:  7.44 | PDE Loss:  -0.097 | Function Loss:  7.44
# Total loss:  7.325 | PDE Loss:  -0.119 | Function Loss:  7.325
# Total loss:  7.082 | PDE Loss:  -0.221 | Function Loss:  7.082
# Total loss:  6.833 | PDE Loss:  -0.237 | Function Loss:  6.833
# Total loss:  7.167 | PDE Loss:  -0.236 | Function Loss:  7.167
# Total loss:  6.704 | PDE Loss:  -0.239 | Function Loss:  6.704
# Total loss:  7.001 | PDE Loss:  -0.256 | Function Loss:  7.001
# Total loss:  6.658 | PDE Loss:  -0.243 | Function Loss:  6.658
# Total loss:  6.46 | PDE Loss:  -0.243 | Function Loss:  6.46
# Total loss:  6.347 | PDE Loss:  -0.296 | Function Loss:  6.347
# Total loss:  6.154 | PDE Loss:  -0.291 | Function Loss:  6.154
# Total loss:  6.234 | PDE Loss:  -0.29 | Function Loss:  6.234
# Total loss:  5.967 | PDE Loss:  -0.291 | Function Loss:  5.967
# Total loss:  5.901 | PDE Loss:  -0.289 | Function Loss:  5.901
# Total loss:  5.825 | PDE Loss:  -0.294 | Function Loss:  5.825
# Total loss:  5.797 | PDE Loss:  -0.298 | Function Loss:  5.797
# Total loss:  5.762 | PDE Loss:  -0.306 | Function Loss:  5.762
# Total loss:  5.687 | PDE Loss:  -0.312 | Function Loss:  5.687
# Total loss:  5.631 | PDE Loss:  -0.337 | Function Loss:  5.631
# Total loss:  5.553 | PDE Loss:  -0.342 | Function Loss:  5.553
# Total loss:  5.509 | PDE Loss:  -0.348 | Function Loss:  5.509
# Total loss:  5.498 | PDE Loss:  -0.351 | Function Loss:  5.498
# Total loss:  5.486 | PDE Loss:  -0.355 | Function Loss:  5.486
# Total loss:  5.412 | PDE Loss:  -0.386 | Function Loss:  5.412
# Total loss:  5.374 | PDE Loss:  -0.403 | Function Loss:  5.374
# Total loss:  5.341 | PDE Loss:  -0.414 | Function Loss:  5.341
# Total loss:  5.3 | PDE Loss:  -0.424 | Function Loss:  5.3
# Total loss:  5.272 | PDE Loss:  -0.434 | Function Loss:  5.272
# Total loss:  5.254 | PDE Loss:  -0.433 | Function Loss:  5.254
# Total loss:  5.226 | PDE Loss:  -0.431 | Function Loss:  5.226
# Total loss:  5.179 | PDE Loss:  -0.437 | Function Loss:  5.179
# Total loss:  5.128 | PDE Loss:  -0.437 | Function Loss:  5.128
# Total loss:  5.085 | PDE Loss:  -0.443 | Function Loss:  5.085
# Total loss:  4.996 | PDE Loss:  -0.447 | Function Loss:  4.996
# Total loss:  4.859 | PDE Loss:  -0.441 | Function Loss:  4.859
# Total loss:  4.756 | PDE Loss:  -0.424 | Function Loss:  4.756
# Total loss:  4.694 | PDE Loss:  -0.429 | Function Loss:  4.694
# Total loss:  4.675 | PDE Loss:  -0.431 | Function Loss:  4.675
# Total loss:  4.649 | PDE Loss:  -0.431 | Function Loss:  4.649
# Total loss:  4.63 | PDE Loss:  -0.429 | Function Loss:  4.63
# Total loss:  4.608 | PDE Loss:  -0.427 | Function Loss:  4.608
# Total loss:  4.521 | PDE Loss:  -0.414 | Function Loss:  4.521
# Total loss:  4.445 | PDE Loss:  -0.403 | Function Loss:  4.445
# Total loss:  4.389 | PDE Loss:  -0.399 | Function Loss:  4.389
# Total loss:  4.306 | PDE Loss:  -0.361 | Function Loss:  4.306
# Total loss:  4.21 | PDE Loss:  -0.359 | Function Loss:  4.21
# Total loss:  4.117 | PDE Loss:  -0.349 | Function Loss:  4.117
# Total loss:  4.069 | PDE Loss:  -0.329 | Function Loss:  4.068
# Total loss:  3.953 | PDE Loss:  -0.291 | Function Loss:  3.953
# Total loss:  3.898 | PDE Loss:  -0.302 | Function Loss:  3.898
# Total loss:  4.228 | PDE Loss:  -0.237 | Function Loss:  4.228
# Total loss:  3.763 | PDE Loss:  -0.284 | Function Loss:  3.762
# Total loss:  3.914 | PDE Loss:  -0.251 | Function Loss:  3.914
# Total loss:  3.644 | PDE Loss:  -0.272 | Function Loss:  3.643
# Total loss:  4.174 | PDE Loss:  -0.266 | Function Loss:  4.174
# Total loss:  3.552 | PDE Loss:  -0.271 | Function Loss:  3.551
# Total loss:  3.808 | PDE Loss:  -0.271 | Function Loss:  3.807
# Total loss:  3.523 | PDE Loss:  -0.271 | Function Loss:  3.522
# Total loss:  3.485 | PDE Loss:  -0.268 | Function Loss:  3.484
# Total loss:  3.477 | PDE Loss:  -0.257 | Function Loss:  3.476
# Total loss:  3.429 | PDE Loss:  -0.262 | Function Loss:  3.428
# Total loss:  3.364 | PDE Loss:  -0.254 | Function Loss:  3.362
# Total loss:  3.338 | PDE Loss:  -0.246 | Function Loss:  3.337
# Total loss:  3.356 | PDE Loss:  -0.241 | Function Loss:  3.355
# Total loss:  3.32 | PDE Loss:  -0.244 | Function Loss:  3.318
# Total loss:  3.268 | PDE Loss:  -0.248 | Function Loss:  3.267
# Total loss:  3.231 | PDE Loss:  -0.257 | Function Loss:  3.229
# Total loss:  3.213 | PDE Loss:  -0.262 | Function Loss:  3.212
# Total loss:  3.246 | PDE Loss:  -0.259 | Function Loss:  3.245
# Total loss:  3.194 | PDE Loss:  -0.261 | Function Loss:  3.193
# Total loss:  3.177 | PDE Loss:  -0.258 | Function Loss:  3.175
# Total loss:  3.166 | PDE Loss:  -0.257 | Function Loss:  3.164
# Total loss:  3.159 | PDE Loss:  -0.256 | Function Loss:  3.158
# Total loss:  3.149 | PDE Loss:  -0.256 | Function Loss:  3.147
# Total loss:  3.139 | PDE Loss:  -0.258 | Function Loss:  3.138
# Total loss:  3.129 | PDE Loss:  -0.257 | Function Loss:  3.127
# Total loss:  3.114 | PDE Loss:  -0.258 | Function Loss:  3.112
# Total loss:  3.097 | PDE Loss:  -0.257 | Function Loss:  3.095
# Total loss:  3.084 | PDE Loss:  -0.256 | Function Loss:  3.082
# Total loss:  3.078 | PDE Loss:  -0.256 | Function Loss:  3.076
# Total loss:  3.073 | PDE Loss:  -0.255 | Function Loss:  3.071
# Total loss:  3.065 | PDE Loss:  -0.254 | Function Loss:  3.062
# Total loss:  3.051 | PDE Loss:  -0.252 | Function Loss:  3.049
# Total loss:  3.032 | PDE Loss:  -0.248 | Function Loss:  3.03
# Total loss:  3.009 | PDE Loss:  -0.246 | Function Loss:  3.007
# Total loss:  2.986 | PDE Loss:  -0.244 | Function Loss:  2.984
# Total loss:  2.962 | PDE Loss:  -0.244 | Function Loss:  2.96
# Total loss:  2.946 | PDE Loss:  -0.244 | Function Loss:  2.943
# Total loss:  2.931 | PDE Loss:  -0.246 | Function Loss:  2.928
# Total loss:  2.916 | PDE Loss:  -0.249 | Function Loss:  2.914
# Total loss:  2.902 | PDE Loss:  -0.252 | Function Loss:  2.899
# Total loss:  2.898 | PDE Loss:  -0.256 | Function Loss:  2.895
# Total loss:  2.894 | PDE Loss:  -0.255 | Function Loss:  2.891
# Total loss:  2.892 | PDE Loss:  -0.254 | Function Loss:  2.889
# Total loss:  2.89 | PDE Loss:  -0.253 | Function Loss:  2.887
# Total loss:  2.889 | PDE Loss:  -0.252 | Function Loss:  2.886
# Total loss:  2.887 | PDE Loss:  -0.251 | Function Loss:  2.884
# Total loss:  2.884 | PDE Loss:  -0.248 | Function Loss:  2.88
# Total loss:  2.876 | PDE Loss:  -0.244 | Function Loss:  2.873
# Total loss:  2.863 | PDE Loss:  -0.235 | Function Loss:  2.86
# Total loss:  2.849 | PDE Loss:  -0.228 | Function Loss:  2.845
# Total loss:  2.828 | PDE Loss:  -0.221 | Function Loss:  2.824
# Total loss:  2.823 | PDE Loss:  -0.206 | Function Loss:  2.819
# Total loss:  2.81 | PDE Loss:  -0.212 | Function Loss:  2.805
# Total loss:  2.774 | PDE Loss:  -0.205 | Function Loss:  2.769
# Total loss:  2.748 | PDE Loss:  -0.191 | Function Loss:  2.743
# Total loss:  2.72 | PDE Loss:  -0.186 | Function Loss:  2.714
# Total loss:  2.697 | PDE Loss:  -0.177 | Function Loss:  2.691
# Total loss:  2.782 | PDE Loss:  -0.154 | Function Loss:  2.777
# Total loss:  2.681 | PDE Loss:  -0.17 | Function Loss:  2.675
# Total loss:  2.664 | PDE Loss:  -0.166 | Function Loss:  2.658
# Total loss:  2.648 | PDE Loss:  -0.162 | Function Loss:  2.641
# Total loss:  2.63 | PDE Loss:  -0.154 | Function Loss:  2.623
# Total loss:  2.617 | PDE Loss:  -0.15 | Function Loss:  2.609
# Total loss:  2.606 | PDE Loss:  -0.141 | Function Loss:  2.598
# Total loss:  2.599 | PDE Loss:  -0.137 | Function Loss:  2.591
# Total loss:  2.592 | PDE Loss:  -0.135 | Function Loss:  2.584
# Total loss:  2.588 | PDE Loss:  -0.133 | Function Loss:  2.58
# Total loss:  2.585 | PDE Loss:  -0.133 | Function Loss:  2.576
# Total loss:  2.579 | PDE Loss:  -0.131 | Function Loss:  2.571
# Total loss:  2.571 | PDE Loss:  -0.13 | Function Loss:  2.562
# Total loss:  2.564 | PDE Loss:  -0.125 | Function Loss:  2.555
# Total loss:  2.558 | PDE Loss:  -0.123 | Function Loss:  2.548
# Total loss:  2.552 | PDE Loss:  -0.119 | Function Loss:  2.542
# Total loss:  2.549 | PDE Loss:  -0.117 | Function Loss:  2.539
# Total loss:  2.547 | PDE Loss:  -0.115 | Function Loss:  2.537
# Total loss:  2.545 | PDE Loss:  -0.113 | Function Loss:  2.535
# Total loss:  2.542 | PDE Loss:  -0.109 | Function Loss:  2.532
# Total loss:  2.538 | PDE Loss:  -0.107 | Function Loss:  2.528
# Total loss:  2.533 | PDE Loss:  -0.102 | Function Loss:  2.522
# Total loss:  2.526 | PDE Loss:  -0.099 | Function Loss:  2.515
# Total loss:  2.518 | PDE Loss:  -0.096 | Function Loss:  2.508
# Total loss:  2.508 | PDE Loss:  -0.094 | Function Loss:  2.497
# Total loss:  2.498 | PDE Loss:  -0.092 | Function Loss:  2.487
# Total loss:  2.485 | PDE Loss:  -0.093 | Function Loss:  2.474
# Total loss:  2.474 | PDE Loss:  -0.095 | Function Loss:  2.462
# Total loss:  2.466 | PDE Loss:  -0.098 | Function Loss:  2.454
# Total loss:  2.462 | PDE Loss:  -0.101 | Function Loss:  2.45
# Total loss:  2.46 | PDE Loss:  -0.103 | Function Loss:  2.448
# Total loss:  2.459 | PDE Loss:  -0.104 | Function Loss:  2.446
# Total loss:  2.458 | PDE Loss:  -0.105 | Function Loss:  2.446
# Total loss:  2.457 | PDE Loss:  -0.107 | Function Loss:  2.445
# Total loss:  2.456 | PDE Loss:  -0.108 | Function Loss:  2.444
# Total loss:  2.454 | PDE Loss:  -0.109 | Function Loss:  2.442
# Total loss:  2.45 | PDE Loss:  -0.11 | Function Loss:  2.438
# Total loss:  2.443 | PDE Loss:  -0.111 | Function Loss:  2.43
# Total loss:  2.431 | PDE Loss:  -0.111 | Function Loss:  2.419
# Total loss:  2.415 | PDE Loss:  -0.108 | Function Loss:  2.402
# Total loss:  2.401 | PDE Loss:  -0.103 | Function Loss:  2.387
# Total loss:  2.391 | PDE Loss:  -0.098 | Function Loss:  2.376
# Total loss:  2.385 | PDE Loss:  -0.092 | Function Loss:  2.371
# Total loss:  2.381 | PDE Loss:  -0.089 | Function Loss:  2.366
# Total loss:  2.378 | PDE Loss:  -0.087 | Function Loss:  2.363
# Total loss:  2.377 | PDE Loss:  -0.085 | Function Loss:  2.362
# Total loss:  2.374 | PDE Loss:  -0.084 | Function Loss:  2.359
# Total loss:  2.37 | PDE Loss:  -0.081 | Function Loss:  2.354
# Total loss:  2.362 | PDE Loss:  -0.077 | Function Loss:  2.346
# Total loss:  2.352 | PDE Loss:  -0.072 | Function Loss:  2.335
# Total loss:  2.337 | PDE Loss:  -0.066 | Function Loss:  2.319
# Total loss:  2.318 | PDE Loss:  -0.059 | Function Loss:  2.299
# Total loss:  2.368 | PDE Loss:  -0.04 | Function Loss:  2.351
# Total loss:  2.308 | PDE Loss:  -0.052 | Function Loss:  2.289
# Total loss:  2.299 | PDE Loss:  -0.05 | Function Loss:  2.279
# Total loss:  2.292 | PDE Loss:  -0.046 | Function Loss:  2.271
# Total loss:  2.283 | PDE Loss:  -0.044 | Function Loss:  2.262
# Total loss:  2.273 | PDE Loss:  -0.042 | Function Loss:  2.251
# Total loss:  2.247 | PDE Loss:  -0.038 | Function Loss:  2.224
# Total loss:  2.228 | PDE Loss:  -0.034 | Function Loss:  2.203
# Total loss:  2.224 | PDE Loss:  -0.028 | Function Loss:  2.199
# Total loss:  2.22 | PDE Loss:  -0.03 | Function Loss:  2.194
# Total loss:  2.204 | PDE Loss:  -0.028 | Function Loss:  2.178
# Total loss:  2.19 | PDE Loss:  -0.024 | Function Loss:  2.162
# Total loss:  2.186 | PDE Loss:  -0.022 | Function Loss:  2.158
# Total loss:  2.181 | PDE Loss:  -0.019 | Function Loss:  2.152
# Total loss:  2.174 | PDE Loss:  -0.016 | Function Loss:  2.145
# Total loss:  2.165 | PDE Loss:  -0.011 | Function Loss:  2.135
# Total loss:  2.153 | PDE Loss:  -0.006 | Function Loss:  2.121
# Total loss:  2.147 | PDE Loss:  0.002 | Function Loss:  2.115
# Total loss:  2.142 | PDE Loss:  -0.001 | Function Loss:  2.109
# Total loss:  2.133 | PDE Loss:  0.001 | Function Loss:  2.099
# Total loss:  2.162 | PDE Loss:  0.011 | Function Loss:  2.131
# Total loss:  2.128 | PDE Loss:  0.004 | Function Loss:  2.094
# Total loss:  2.114 | PDE Loss:  0.006 | Function Loss:  2.079
# Total loss:  2.102 | PDE Loss:  0.01 | Function Loss:  2.066
# Total loss:  2.088 | PDE Loss:  0.013 | Function Loss:  2.05
# Total loss:  2.078 | PDE Loss:  0.018 | Function Loss:  2.039
# Total loss:  2.067 | PDE Loss:  0.019 | Function Loss:  2.026
# Total loss:  2.056 | PDE Loss:  0.02 | Function Loss:  2.014
# Total loss:  2.039 | PDE Loss:  0.019 | Function Loss:  1.996
# Total loss:  2.028 | PDE Loss:  0.019 | Function Loss:  1.983
# Total loss:  2.024 | PDE Loss:  0.019 | Function Loss:  1.979
# Total loss:  2.023 | PDE Loss:  0.018 | Function Loss:  1.978
# Total loss:  2.021 | PDE Loss:  0.018 | Function Loss:  1.976
# Total loss:  2.02 | PDE Loss:  0.018 | Function Loss:  1.974
# Total loss:  2.018 | PDE Loss:  0.018 | Function Loss:  1.972
# Total loss:  2.015 | PDE Loss:  0.017 | Function Loss:  1.969
# Total loss:  2.012 | PDE Loss:  0.016 | Function Loss:  1.965
# Total loss:  2.005 | PDE Loss:  0.015 | Function Loss:  1.959
# Total loss:  1.999 | PDE Loss:  0.014 | Function Loss:  1.951
# Total loss:  1.993 | PDE Loss:  0.011 | Function Loss:  1.945
# Total loss:  1.988 | PDE Loss:  0.011 | Function Loss:  1.94
# Total loss:  1.983 | PDE Loss:  0.01 | Function Loss:  1.935
# Total loss:  1.978 | PDE Loss:  0.01 | Function Loss:  1.928
# Total loss:  1.972 | PDE Loss:  0.01 | Function Loss:  1.922
# Total loss:  1.968 | PDE Loss:  0.01 | Function Loss:  1.917
# Total loss:  1.963 | PDE Loss:  0.01 | Function Loss:  1.911
# Total loss:  1.955 | PDE Loss:  0.011 | Function Loss:  1.903
# Total loss:  1.945 | PDE Loss:  0.012 | Function Loss:  1.891
# Total loss:  1.93 | PDE Loss:  0.014 | Function Loss:  1.874
# Total loss:  1.914 | PDE Loss:  0.017 | Function Loss:  1.856
# Total loss:  1.911 | PDE Loss:  0.022 | Function Loss:  1.851
# Total loss:  1.904 | PDE Loss:  0.02 | Function Loss:  1.844
# Total loss:  1.896 | PDE Loss:  0.021 | Function Loss:  1.834
# Total loss:  1.888 | PDE Loss:  0.023 | Function Loss:  1.824
# Total loss:  1.883 | PDE Loss:  0.026 | Function Loss:  1.818
# Total loss:  1.881 | PDE Loss:  0.026 | Function Loss:  1.816
# Total loss:  1.879 | PDE Loss:  0.026 | Function Loss:  1.813
# Total loss:  1.876 | PDE Loss:  0.027 | Function Loss:  1.809
# Total loss:  1.87 | PDE Loss:  0.028 | Function Loss:  1.803
# Total loss:  1.86 | PDE Loss:  0.029 | Function Loss:  1.791
# Total loss:  1.851 | PDE Loss:  0.031 | Function Loss:  1.78
# Total loss:  1.838 | PDE Loss:  0.033 | Function Loss:  1.764
# Total loss:  1.813 | PDE Loss:  0.035 | Function Loss:  1.734
# Total loss:  1.789 | PDE Loss:  0.037 | Function Loss:  1.705
# Total loss:  1.771 | PDE Loss:  0.038 | Function Loss:  1.682
# Total loss:  1.785 | PDE Loss:  0.037 | Function Loss:  1.699
# Total loss:  1.766 | PDE Loss:  0.038 | Function Loss:  1.676
# Total loss:  1.758 | PDE Loss:  0.039 | Function Loss:  1.666
# Total loss:  1.75 | PDE Loss:  0.041 | Function Loss:  1.655
# Total loss:  1.744 | PDE Loss:  0.042 | Function Loss:  1.647
# Total loss:  1.738 | PDE Loss:  0.043 | Function Loss:  1.64
# Total loss:  1.727 | PDE Loss:  0.045 | Function Loss:  1.625
# Total loss:  1.71 | PDE Loss:  0.048 | Function Loss:  1.603
# Total loss:  1.688 | PDE Loss:  0.05 | Function Loss:  1.575
# Total loss:  1.678 | PDE Loss:  0.054 | Function Loss:  1.56
# Total loss:  1.663 | PDE Loss:  0.054 | Function Loss:  1.54
# Total loss:  1.65 | PDE Loss:  0.057 | Function Loss:  1.522
# Total loss:  1.642 | PDE Loss:  0.058 | Function Loss:  1.511
# Total loss:  1.634 | PDE Loss:  0.06 | Function Loss:  1.499
# Total loss:  1.627 | PDE Loss:  0.064 | Function Loss:  1.489
# Total loss:  1.619 | PDE Loss:  0.066 | Function Loss:  1.476
# Total loss:  1.613 | PDE Loss:  0.068 | Function Loss:  1.468
# Total loss:  1.611 | PDE Loss:  0.07 | Function Loss:  1.464
# Total loss:  1.607 | PDE Loss:  0.07 | Function Loss:  1.458
# Total loss:  1.599 | PDE Loss:  0.072 | Function Loss:  1.447
# Total loss:  1.592 | PDE Loss:  0.073 | Function Loss:  1.436
# Total loss:  1.585 | PDE Loss:  0.075 | Function Loss:  1.425
# Total loss:  1.578 | PDE Loss:  0.077 | Function Loss:  1.413
# Total loss:  1.572 | PDE Loss:  0.079 | Function Loss:  1.403
# Total loss:  1.567 | PDE Loss:  0.08 | Function Loss:  1.396
# Total loss:  1.563 | PDE Loss:  0.08 | Function Loss:  1.39
# Total loss:  1.56 | PDE Loss:  0.081 | Function Loss:  1.384
# Total loss:  1.557 | PDE Loss:  0.08 | Function Loss:  1.381
# Total loss:  1.555 | PDE Loss:  0.08 | Function Loss:  1.378
# Total loss:  1.554 | PDE Loss:  0.079 | Function Loss:  1.377
# Total loss:  1.553 | PDE Loss:  0.078 | Function Loss:  1.376
# Total loss:  1.552 | PDE Loss:  0.077 | Function Loss:  1.374
# Total loss:  1.549 | PDE Loss:  0.076 | Function Loss:  1.371
# Total loss:  1.546 | PDE Loss:  0.075 | Function Loss:  1.367
# Total loss:  1.543 | PDE Loss:  0.073 | Function Loss:  1.362
# Total loss:  1.539 | PDE Loss:  0.072 | Function Loss:  1.357
# Total loss:  1.534 | PDE Loss:  0.072 | Function Loss:  1.35
# Total loss:  1.529 | PDE Loss:  0.071 | Function Loss:  1.343
# Total loss:  1.525 | PDE Loss:  0.072 | Function Loss:  1.336
# Total loss:  1.52 | PDE Loss:  0.071 | Function Loss:  1.33
# Total loss:  1.517 | PDE Loss:  0.072 | Function Loss:  1.325
# Total loss:  1.513 | PDE Loss:  0.074 | Function Loss:  1.316
# Total loss:  1.509 | PDE Loss:  0.075 | Function Loss:  1.309
# Total loss:  1.507 | PDE Loss:  0.075 | Function Loss:  1.306
# Total loss:  1.505 | PDE Loss:  0.076 | Function Loss:  1.303
# Total loss:  1.502 | PDE Loss:  0.077 | Function Loss:  1.298
# Total loss:  1.499 | PDE Loss:  0.078 | Function Loss:  1.292
# Total loss:  1.494 | PDE Loss:  0.08 | Function Loss:  1.283
# Total loss:  1.491 | PDE Loss:  0.081 | Function Loss:  1.277
# Total loss:  1.486 | PDE Loss:  0.083 | Function Loss:  1.268
# Total loss:  1.483 | PDE Loss:  0.084 | Function Loss:  1.262
# Total loss:  1.48 | PDE Loss:  0.086 | Function Loss:  1.256
# Total loss:  1.478 | PDE Loss:  0.087 | Function Loss:  1.251
# Total loss:  1.477 | PDE Loss:  0.088 | Function Loss:  1.249
# Total loss:  1.475 | PDE Loss:  0.088 | Function Loss:  1.245
# Total loss:  1.473 | PDE Loss:  0.088 | Function Loss:  1.242
# Total loss:  1.471 | PDE Loss:  0.088 | Function Loss:  1.239
# Total loss:  1.469 | PDE Loss:  0.088 | Function Loss:  1.235
# Total loss:  1.466 | PDE Loss:  0.087 | Function Loss:  1.232
# Total loss:  1.465 | PDE Loss:  0.087 | Function Loss:  1.23
# Total loss:  1.464 | PDE Loss:  0.087 | Function Loss:  1.228
# Total loss:  1.462 | PDE Loss:  0.086 | Function Loss:  1.225
# Total loss:  1.46 | PDE Loss:  0.085 | Function Loss:  1.223
# Total loss:  1.458 | PDE Loss:  0.084 | Function Loss:  1.219
# Total loss:  1.455 | PDE Loss:  0.083 | Function Loss:  1.216
# Total loss:  1.453 | PDE Loss:  0.082 | Function Loss:  1.213
# Total loss:  1.452 | PDE Loss:  0.081 | Function Loss:  1.211
# Total loss:  1.45 | PDE Loss:  0.079 | Function Loss:  1.209
# Total loss:  1.45 | PDE Loss:  0.079 | Function Loss:  1.208
# Total loss:  1.449 | PDE Loss:  0.079 | Function Loss:  1.208
# Total loss:  1.449 | PDE Loss:  0.079 | Function Loss:  1.207
# Total loss:  1.449 | PDE Loss:  0.08 | Function Loss:  1.206
# Total loss:  1.448 | PDE Loss:  0.08 | Function Loss:  1.206
# Total loss:  1.448 | PDE Loss:  0.08 | Function Loss:  1.205
# Total loss:  1.448 | PDE Loss:  0.08 | Function Loss:  1.205
# Total loss:  1.448 | PDE Loss:  0.081 | Function Loss:  1.204
# Total loss:  1.447 | PDE Loss:  0.081 | Function Loss:  1.203
# Total loss:  1.446 | PDE Loss:  0.081 | Function Loss:  1.201
# Total loss:  1.445 | PDE Loss:  0.082 | Function Loss:  1.198
# Total loss:  1.442 | PDE Loss:  0.083 | Function Loss:  1.193
# Total loss:  1.439 | PDE Loss:  0.086 | Function Loss:  1.184
# Total loss:  1.435 | PDE Loss:  0.087 | Function Loss:  1.177
# Total loss:  1.429 | PDE Loss:  0.088 | Function Loss:  1.164
# Total loss:  1.421 | PDE Loss:  0.091 | Function Loss:  1.148
# Total loss:  1.411 | PDE Loss:  0.092 | Function Loss:  1.128
# Total loss:  1.41 | PDE Loss:  0.09 | Function Loss:  1.127
# Total loss:  1.402 | PDE Loss:  0.091 | Function Loss:  1.111
# Total loss:  1.399 | PDE Loss:  0.091 | Function Loss:  1.106
# Total loss:  1.397 | PDE Loss:  0.091 | Function Loss:  1.1
# Total loss:  1.396 | PDE Loss:  0.092 | Function Loss:  1.098
# Total loss:  1.394 | PDE Loss:  0.092 | Function Loss:  1.094
# Total loss:  1.394 | PDE Loss:  0.093 | Function Loss:  1.093
# Total loss:  1.392 | PDE Loss:  0.093 | Function Loss:  1.089
# Total loss:  1.391 | PDE Loss:  0.094 | Function Loss:  1.086
# Total loss:  1.389 | PDE Loss:  0.095 | Function Loss:  1.081
# Total loss:  1.387 | PDE Loss:  0.098 | Function Loss:  1.073
# Total loss:  1.383 | PDE Loss:  0.101 | Function Loss:  1.061
# Total loss:  1.38 | PDE Loss:  0.103 | Function Loss:  1.052
# Total loss:  1.376 | PDE Loss:  0.106 | Function Loss:  1.042
# Total loss:  1.378 | PDE Loss:  0.11 | Function Loss:  1.04
# Total loss:  1.375 | PDE Loss:  0.108 | Function Loss:  1.036
# Total loss:  1.373 | PDE Loss:  0.109 | Function Loss:  1.03
# Total loss:  1.371 | PDE Loss:  0.11 | Function Loss:  1.025
# Total loss:  1.369 | PDE Loss:  0.111 | Function Loss:  1.021
# Total loss:  1.368 | PDE Loss:  0.111 | Function Loss:  1.018
# Total loss:  1.367 | PDE Loss:  0.111 | Function Loss:  1.015
# Total loss:  1.366 | PDE Loss:  0.111 | Function Loss:  1.012
# Total loss:  1.364 | PDE Loss:  0.111 | Function Loss:  1.01
# Total loss:  1.363 | PDE Loss:  0.111 | Function Loss:  1.006
# Total loss:  1.361 | PDE Loss:  0.111 | Function Loss:  1.002
# Total loss:  1.359 | PDE Loss:  0.111 | Function Loss:  0.998
# Total loss:  1.358 | PDE Loss:  0.111 | Function Loss:  0.994
# Total loss:  1.356 | PDE Loss:  0.112 | Function Loss:  0.99
# Total loss:  1.355 | PDE Loss:  0.113 | Function Loss:  0.986
# Total loss:  1.354 | PDE Loss:  0.114 | Function Loss:  0.982
# Total loss:  1.353 | PDE Loss:  0.115 | Function Loss:  0.978
# Total loss:  1.352 | PDE Loss:  0.116 | Function Loss:  0.973
# Total loss:  1.35 | PDE Loss:  0.117 | Function Loss:  0.969
# Total loss:  1.349 | PDE Loss:  0.118 | Function Loss:  0.964
# Total loss:  1.349 | PDE Loss:  0.12 | Function Loss:  0.961
# Total loss:  1.348 | PDE Loss:  0.12 | Function Loss:  0.959
# Total loss:  1.348 | PDE Loss:  0.121 | Function Loss:  0.958
# Total loss:  1.347 | PDE Loss:  0.121 | Function Loss:  0.956
# Total loss:  1.347 | PDE Loss:  0.121 | Function Loss:  0.955
# Total loss:  1.347 | PDE Loss:  0.122 | Function Loss:  0.954
# Total loss:  1.347 | PDE Loss:  0.122 | Function Loss:  0.953
# Total loss:  1.347 | PDE Loss:  0.122 | Function Loss:  0.953
# Total loss:  1.346 | PDE Loss:  0.122 | Function Loss:  0.952
# Total loss:  1.346 | PDE Loss:  0.122 | Function Loss:  0.952
# Total loss:  1.346 | PDE Loss:  0.122 | Function Loss:  0.951
# Total loss:  1.346 | PDE Loss:  0.122 | Function Loss:  0.951
# Total loss:  1.346 | PDE Loss:  0.123 | Function Loss:  0.95
# Total loss:  1.346 | PDE Loss:  0.123 | Function Loss:  0.949
# Total loss:  1.346 | PDE Loss:  0.124 | Function Loss:  0.948
# Total loss:  1.345 | PDE Loss:  0.124 | Function Loss:  0.946
# Total loss:  1.345 | PDE Loss:  0.125 | Function Loss:  0.945
# Total loss:  1.345 | PDE Loss:  0.126 | Function Loss:  0.942
# Total loss:  1.345 | PDE Loss:  0.127 | Function Loss:  0.94
# Total loss:  1.344 | PDE Loss:  0.128 | Function Loss:  0.938
# Total loss:  1.344 | PDE Loss:  0.129 | Function Loss:  0.935
# Total loss:  1.343 | PDE Loss:  0.13 | Function Loss:  0.933
# Total loss:  1.343 | PDE Loss:  0.13 | Function Loss:  0.93
# Total loss:  1.342 | PDE Loss:  0.131 | Function Loss:  0.927
# Total loss:  1.341 | PDE Loss:  0.132 | Function Loss:  0.924
# Total loss:  1.341 | PDE Loss:  0.133 | Function Loss:  0.921
# Total loss:  1.34 | PDE Loss:  0.132 | Function Loss:  0.921
# Total loss:  1.34 | PDE Loss:  0.132 | Function Loss:  0.92
# Total loss:  1.34 | PDE Loss:  0.132 | Function Loss:  0.92
# Total loss:  1.34 | PDE Loss:  0.132 | Function Loss:  0.92
# Total loss:  1.34 | PDE Loss:  0.132 | Function Loss:  0.92
# Total loss:  1.339 | PDE Loss:  0.132 | Function Loss:  0.919
# Total loss:  1.339 | PDE Loss:  0.131 | Function Loss:  0.919
# Total loss:  1.338 | PDE Loss:  0.13 | Function Loss:  0.919
# Total loss:  1.337 | PDE Loss:  0.129 | Function Loss:  0.918
# Total loss:  1.336 | PDE Loss:  0.128 | Function Loss:  0.916
# Total loss:  1.334 | PDE Loss:  0.127 | Function Loss:  0.913
# Total loss:  1.332 | PDE Loss:  0.126 | Function Loss:  0.909
# Total loss:  1.329 | PDE Loss:  0.124 | Function Loss:  0.904
# Total loss:  1.326 | PDE Loss:  0.124 | Function Loss:  0.897
# Total loss:  1.324 | PDE Loss:  0.123 | Function Loss:  0.894
# Total loss:  1.322 | PDE Loss:  0.124 | Function Loss:  0.886
# Total loss:  1.321 | PDE Loss:  0.124 | Function Loss:  0.881
# Total loss:  1.319 | PDE Loss:  0.124 | Function Loss:  0.877
# Total loss:  1.318 | PDE Loss:  0.123 | Function Loss:  0.874
# Total loss:  1.316 | PDE Loss:  0.123 | Function Loss:  0.871
# Total loss:  1.315 | PDE Loss:  0.123 | Function Loss:  0.869
# Total loss:  1.315 | PDE Loss:  0.122 | Function Loss:  0.868
# Total loss:  1.314 | PDE Loss:  0.122 | Function Loss:  0.866
# Total loss:  1.313 | PDE Loss:  0.121 | Function Loss:  0.865
# Total loss:  1.311 | PDE Loss:  0.12 | Function Loss:  0.863
# Total loss:  1.31 | PDE Loss:  0.119 | Function Loss:  0.861
# Total loss:  1.308 | PDE Loss:  0.117 | Function Loss:  0.859
# Total loss:  1.307 | PDE Loss:  0.116 | Function Loss:  0.857
# Total loss:  1.304 | PDE Loss:  0.114 | Function Loss:  0.853
# Total loss:  1.303 | PDE Loss:  0.112 | Function Loss:  0.853
# Total loss:  1.3 | PDE Loss:  0.113 | Function Loss:  0.845
# Total loss:  1.296 | PDE Loss:  0.111 | Function Loss:  0.835
# Total loss:  1.292 | PDE Loss:  0.11 | Function Loss:  0.827
# Total loss:  1.29 | PDE Loss:  0.11 | Function Loss:  0.821
# Total loss:  1.289 | PDE Loss:  0.109 | Function Loss:  0.817
# Total loss:  1.286 | PDE Loss:  0.108 | Function Loss:  0.813
# Total loss:  1.286 | PDE Loss:  0.109 | Function Loss:  0.81
# Total loss:  1.283 | PDE Loss:  0.108 | Function Loss:  0.804
# Total loss:  1.281 | PDE Loss:  0.106 | Function Loss:  0.801
# Total loss:  1.278 | PDE Loss:  0.106 | Function Loss:  0.793
# Total loss:  1.274 | PDE Loss:  0.105 | Function Loss:  0.783
# Total loss:  1.272 | PDE Loss:  0.104 | Function Loss:  0.777
# Total loss:  1.27 | PDE Loss:  0.104 | Function Loss:  0.774
# Total loss:  1.269 | PDE Loss:  0.103 | Function Loss:  0.771
# Total loss:  1.268 | PDE Loss:  0.102 | Function Loss:  0.77
# Total loss:  1.267 | PDE Loss:  0.101 | Function Loss:  0.769
# Total loss:  1.267 | PDE Loss:  0.101 | Function Loss:  0.768
# Total loss:  1.266 | PDE Loss:  0.101 | Function Loss:  0.767
# Total loss:  1.266 | PDE Loss:  0.1 | Function Loss:  0.767
# Total loss:  1.265 | PDE Loss:  0.1 | Function Loss:  0.766
# Total loss:  1.265 | PDE Loss:  0.099 | Function Loss:  0.765
# Total loss:  1.264 | PDE Loss:  0.099 | Function Loss:  0.764
# Total loss:  1.264 | PDE Loss:  0.099 | Function Loss:  0.764
# Total loss:  1.264 | PDE Loss:  0.099 | Function Loss:  0.764
# Total loss:  1.264 | PDE Loss:  0.099 | Function Loss:  0.764
# Total loss:  1.263 | PDE Loss:  0.098 | Function Loss:  0.764
# Total loss:  1.263 | PDE Loss:  0.098 | Function Loss:  0.763
# Total loss:  1.263 | PDE Loss:  0.098 | Function Loss:  0.764
# Total loss:  1.263 | PDE Loss:  0.097 | Function Loss:  0.764
# Total loss:  1.263 | PDE Loss:  0.097 | Function Loss:  0.764
# Total loss:  1.262 | PDE Loss:  0.097 | Function Loss:  0.764
# Total loss:  1.262 | PDE Loss:  0.096 | Function Loss:  0.764
# Total loss:  1.261 | PDE Loss:  0.096 | Function Loss:  0.763
# Total loss:  1.261 | PDE Loss:  0.095 | Function Loss:  0.762
# Total loss:  1.26 | PDE Loss:  0.094 | Function Loss:  0.76
# Total loss:  1.258 | PDE Loss:  0.093 | Function Loss:  0.756
# Total loss:  1.256 | PDE Loss:  0.091 | Function Loss:  0.754
# Total loss:  1.253 | PDE Loss:  0.089 | Function Loss:  0.749
# Total loss:  1.25 | PDE Loss:  0.087 | Function Loss:  0.743
# Total loss:  1.247 | PDE Loss:  0.086 | Function Loss:  0.74
# Total loss:  1.244 | PDE Loss:  0.084 | Function Loss:  0.734
# Total loss:  1.243 | PDE Loss:  0.083 | Function Loss:  0.733
# Total loss:  1.243 | PDE Loss:  0.083 | Function Loss:  0.731
# Total loss:  1.242 | PDE Loss:  0.082 | Function Loss:  0.73
# Total loss:  1.242 | PDE Loss:  0.082 | Function Loss:  0.729
# Total loss:  1.241 | PDE Loss:  0.082 | Function Loss:  0.728
# Total loss:  1.241 | PDE Loss:  0.082 | Function Loss:  0.727
# Total loss:  1.239 | PDE Loss:  0.081 | Function Loss:  0.723
# Total loss:  1.237 | PDE Loss:  0.081 | Function Loss:  0.718
# Total loss:  1.234 | PDE Loss:  0.08 | Function Loss:  0.71
# Total loss:  1.233 | PDE Loss:  0.079 | Function Loss:  0.71
# Total loss:  1.23 | PDE Loss:  0.079 | Function Loss:  0.698
# Total loss:  1.228 | PDE Loss:  0.079 | Function Loss:  0.689
# Total loss:  1.225 | PDE Loss:  0.079 | Function Loss:  0.682
# Total loss:  1.223 | PDE Loss:  0.078 | Function Loss:  0.676
# Total loss:  1.222 | PDE Loss:  0.078 | Function Loss:  0.674
# Total loss:  1.222 | PDE Loss:  0.077 | Function Loss:  0.673
# Total loss:  1.221 | PDE Loss:  0.077 | Function Loss:  0.673
# Total loss:  1.22 | PDE Loss:  0.076 | Function Loss:  0.672
# Total loss:  1.219 | PDE Loss:  0.075 | Function Loss:  0.67
# Total loss:  1.218 | PDE Loss:  0.073 | Function Loss:  0.67
# Total loss:  1.217 | PDE Loss:  0.072 | Function Loss:  0.67
# Total loss:  1.216 | PDE Loss:  0.07 | Function Loss:  0.671
# Total loss:  1.215 | PDE Loss:  0.069 | Function Loss:  0.672
# Total loss:  1.214 | PDE Loss:  0.068 | Function Loss:  0.672
# Total loss:  1.214 | PDE Loss:  0.064 | Function Loss:  0.681
# Total loss:  1.213 | PDE Loss:  0.066 | Function Loss:  0.673
# Total loss:  1.212 | PDE Loss:  0.065 | Function Loss:  0.671
# Total loss:  1.21 | PDE Loss:  0.064 | Function Loss:  0.664
# Total loss:  1.208 | PDE Loss:  0.063 | Function Loss:  0.66
# Total loss:  1.204 | PDE Loss:  0.062 | Function Loss:  0.65
# Total loss:  1.203 | PDE Loss:  0.06 | Function Loss:  0.652
# Total loss:  1.2 | PDE Loss:  0.059 | Function Loss:  0.642
# Total loss:  1.197 | PDE Loss:  0.058 | Function Loss:  0.635
# Total loss:  1.195 | PDE Loss:  0.056 | Function Loss:  0.63
# Total loss:  1.191 | PDE Loss:  0.054 | Function Loss:  0.622
# Total loss:  1.187 | PDE Loss:  0.051 | Function Loss:  0.618
# Total loss:  1.186 | PDE Loss:  0.046 | Function Loss:  0.625
# Total loss:  1.181 | PDE Loss:  0.045 | Function Loss:  0.612
# Total loss:  1.18 | PDE Loss:  0.043 | Function Loss:  0.611
# Total loss:  1.178 | PDE Loss:  0.043 | Function Loss:  0.602
# Total loss:  1.175 | PDE Loss:  0.042 | Function Loss:  0.597
# Total loss:  1.174 | PDE Loss:  0.041 | Function Loss:  0.593
# Total loss:  1.172 | PDE Loss:  0.038 | Function Loss:  0.594
# Total loss:  1.171 | PDE Loss:  0.037 | Function Loss:  0.592
# Total loss:  1.17 | PDE Loss:  0.036 | Function Loss:  0.593
# Total loss:  1.169 | PDE Loss:  0.034 | Function Loss:  0.595
# Total loss:  1.168 | PDE Loss:  0.033 | Function Loss:  0.595
# Total loss:  1.168 | PDE Loss:  0.032 | Function Loss:  0.597
# Total loss:  1.167 | PDE Loss:  0.031 | Function Loss:  0.598
# Total loss:  1.167 | PDE Loss:  0.028 | Function Loss:  0.603
# Total loss:  1.166 | PDE Loss:  0.028 | Function Loss:  0.602
# Total loss:  1.166 | PDE Loss:  0.028 | Function Loss:  0.602
# Total loss:  1.166 | PDE Loss:  0.027 | Function Loss:  0.602
# Total loss:  1.165 | PDE Loss:  0.026 | Function Loss:  0.602
# Total loss:  1.165 | PDE Loss:  0.026 | Function Loss:  0.602
# Total loss:  1.164 | PDE Loss:  0.025 | Function Loss:  0.602
# Total loss:  1.164 | PDE Loss:  0.025 | Function Loss:  0.601
# Total loss:  1.163 | PDE Loss:  0.024 | Function Loss:  0.6
# Total loss:  1.163 | PDE Loss:  0.025 | Function Loss:  0.599
# Total loss:  1.162 | PDE Loss:  0.024 | Function Loss:  0.597
# Total loss:  1.162 | PDE Loss:  0.025 | Function Loss:  0.594
# Total loss:  1.161 | PDE Loss:  0.025 | Function Loss:  0.591
# Total loss:  1.16 | PDE Loss:  0.025 | Function Loss:  0.589
# Total loss:  1.159 | PDE Loss:  0.025 | Function Loss:  0.585
# Total loss:  1.158 | PDE Loss:  0.023 | Function Loss:  0.584
# Total loss:  1.157 | PDE Loss:  0.023 | Function Loss:  0.581
# Total loss:  1.156 | PDE Loss:  0.022 | Function Loss:  0.581
# Total loss:  1.155 | PDE Loss:  0.02 | Function Loss:  0.581
# Total loss:  1.154 | PDE Loss:  0.019 | Function Loss:  0.583
# Total loss:  1.153 | PDE Loss:  0.017 | Function Loss:  0.584
# Total loss:  1.152 | PDE Loss:  0.015 | Function Loss:  0.586
# Total loss:  1.151 | PDE Loss:  0.012 | Function Loss:  0.587
# Total loss:  1.15 | PDE Loss:  0.007 | Function Loss:  0.598
# Total loss:  1.15 | PDE Loss:  0.009 | Function Loss:  0.591
# Total loss:  1.147 | PDE Loss:  0.005 | Function Loss:  0.594
# Total loss:  1.146 | PDE Loss:  0.003 | Function Loss:  0.593
# Total loss:  1.144 | PDE Loss:  0.001 | Function Loss:  0.592
# Total loss:  1.143 | PDE Loss:  -0.002 | Function Loss:  0.594
# Total loss:  1.142 | PDE Loss:  -0.004 | Function Loss:  0.599
# Total loss:  1.142 | PDE Loss:  -0.007 | Function Loss:  0.603
# Total loss:  1.141 | PDE Loss:  -0.007 | Function Loss:  0.6
# Total loss:  1.14 | PDE Loss:  -0.005 | Function Loss:  0.595
# Total loss:  1.14 | PDE Loss:  -0.005 | Function Loss:  0.595
# Total loss:  1.14 | PDE Loss:  -0.006 | Function Loss:  0.595
# Total loss:  1.139 | PDE Loss:  -0.007 | Function Loss:  0.596
# Total loss:  1.139 | PDE Loss:  -0.008 | Function Loss:  0.597
# Total loss:  1.139 | PDE Loss:  -0.008 | Function Loss:  0.598
# Total loss:  1.139 | PDE Loss:  -0.009 | Function Loss:  0.599
# Total loss:  1.139 | PDE Loss:  -0.01 | Function Loss:  0.601
# Total loss:  1.139 | PDE Loss:  -0.011 | Function Loss:  0.603
# Total loss:  1.138 | PDE Loss:  -0.012 | Function Loss:  0.605
# Total loss:  1.138 | PDE Loss:  -0.014 | Function Loss:  0.608
# Total loss:  1.138 | PDE Loss:  -0.016 | Function Loss:  0.611
# Total loss:  1.137 | PDE Loss:  -0.019 | Function Loss:  0.617
# Total loss:  1.137 | PDE Loss:  -0.02 | Function Loss:  0.619
# Total loss:  1.136 | PDE Loss:  -0.021 | Function Loss:  0.619
# Total loss:  1.135 | PDE Loss:  -0.024 | Function Loss:  0.622
# Total loss:  1.134 | PDE Loss:  -0.026 | Function Loss:  0.622
# Total loss:  1.133 | PDE Loss:  -0.028 | Function Loss:  0.624
# Total loss:  1.131 | PDE Loss:  -0.029 | Function Loss:  0.619
# Total loss:  1.13 | PDE Loss:  -0.031 | Function Loss:  0.623
# Total loss:  1.13 | PDE Loss:  -0.031 | Function Loss:  0.62
# Total loss:  1.129 | PDE Loss:  -0.031 | Function Loss:  0.618
# Total loss:  1.128 | PDE Loss:  -0.031 | Function Loss:  0.616
# Total loss:  1.128 | PDE Loss:  -0.031 | Function Loss:  0.616
# Total loss:  1.128 | PDE Loss:  -0.032 | Function Loss:  0.616
# Total loss:  1.128 | PDE Loss:  -0.032 | Function Loss:  0.616
# Total loss:  1.127 | PDE Loss:  -0.032 | Function Loss:  0.615
# Total loss:  1.127 | PDE Loss:  -0.033 | Function Loss:  0.615
# Total loss:  1.126 | PDE Loss:  -0.033 | Function Loss:  0.615
# Total loss:  1.126 | PDE Loss:  -0.034 | Function Loss:  0.614
# Total loss:  1.126 | PDE Loss:  -0.035 | Function Loss:  0.615
# Total loss:  1.125 | PDE Loss:  -0.035 | Function Loss:  0.615
# Total loss:  1.125 | PDE Loss:  -0.036 | Function Loss:  0.615
# Total loss:  1.124 | PDE Loss:  -0.036 | Function Loss:  0.614
# Total loss:  1.123 | PDE Loss:  -0.037 | Function Loss:  0.614
# Total loss:  1.122 | PDE Loss:  -0.038 | Function Loss:  0.611
# Total loss:  1.122 | PDE Loss:  -0.038 | Function Loss:  0.61
# Total loss:  1.121 | PDE Loss:  -0.038 | Function Loss:  0.608
# Total loss:  1.12 | PDE Loss:  -0.039 | Function Loss:  0.607
# Total loss:  1.119 | PDE Loss:  -0.039 | Function Loss:  0.605
# Total loss:  1.119 | PDE Loss:  -0.04 | Function Loss:  0.606
# Total loss:  1.118 | PDE Loss:  -0.041 | Function Loss:  0.605
# Total loss:  1.118 | PDE Loss:  -0.042 | Function Loss:  0.605
# Total loss:  1.117 | PDE Loss:  -0.044 | Function Loss:  0.607
# Total loss:  1.116 | PDE Loss:  -0.045 | Function Loss:  0.607
# Total loss:  1.115 | PDE Loss:  -0.047 | Function Loss:  0.608
# Total loss:  1.113 | PDE Loss:  -0.049 | Function Loss:  0.607
# Total loss:  1.112 | PDE Loss:  -0.051 | Function Loss:  0.607
# Total loss:  1.111 | PDE Loss:  -0.052 | Function Loss:  0.606
# Total loss:  1.11 | PDE Loss:  -0.054 | Function Loss:  0.607
# Total loss:  1.108 | PDE Loss:  -0.055 | Function Loss:  0.605
# Total loss:  1.107 | PDE Loss:  -0.056 | Function Loss:  0.604
# Total loss:  1.106 | PDE Loss:  -0.057 | Function Loss:  0.603
# Total loss:  1.105 | PDE Loss:  -0.058 | Function Loss:  0.6
# Total loss:  1.104 | PDE Loss:  -0.058 | Function Loss:  0.597
# Total loss:  1.103 | PDE Loss:  -0.059 | Function Loss:  0.597
# Total loss:  1.102 | PDE Loss:  -0.06 | Function Loss:  0.595
# Total loss:  1.101 | PDE Loss:  -0.061 | Function Loss:  0.594
# Total loss:  1.099 | PDE Loss:  -0.063 | Function Loss:  0.591
# Total loss:  1.096 | PDE Loss:  -0.065 | Function Loss:  0.587
# Total loss:  1.093 | PDE Loss:  -0.068 | Function Loss:  0.585
# Total loss:  1.091 | PDE Loss:  -0.07 | Function Loss:  0.582
# Total loss:  1.091 | PDE Loss:  -0.076 | Function Loss:  0.593
# Total loss:  1.089 | PDE Loss:  -0.073 | Function Loss:  0.583
# Total loss:  1.088 | PDE Loss:  -0.074 | Function Loss:  0.582
# Total loss:  1.087 | PDE Loss:  -0.076 | Function Loss:  0.581
# Total loss:  1.085 | PDE Loss:  -0.077 | Function Loss:  0.581
# Total loss:  1.084 | PDE Loss:  -0.08 | Function Loss:  0.582
# Total loss:  1.083 | PDE Loss:  -0.081 | Function Loss:  0.582
# Total loss:  1.083 | PDE Loss:  -0.085 | Function Loss:  0.589
# Total loss:  1.083 | PDE Loss:  -0.083 | Function Loss:  0.585
# Total loss:  1.082 | PDE Loss:  -0.084 | Function Loss:  0.585
# Total loss:  1.081 | PDE Loss:  -0.086 | Function Loss:  0.586
# Total loss:  1.081 | PDE Loss:  -0.088 | Function Loss:  0.588
# Total loss:  1.08 | PDE Loss:  -0.089 | Function Loss:  0.589
# Total loss:  1.08 | PDE Loss:  -0.091 | Function Loss:  0.591
# Total loss:  1.08 | PDE Loss:  -0.091 | Function Loss:  0.593
# Total loss:  1.08 | PDE Loss:  -0.092 | Function Loss:  0.594
# Total loss:  1.079 | PDE Loss:  -0.093 | Function Loss:  0.595
# Total loss:  1.079 | PDE Loss:  -0.094 | Function Loss:  0.596
# Total loss:  1.079 | PDE Loss:  -0.094 | Function Loss:  0.597
# Total loss:  1.079 | PDE Loss:  -0.095 | Function Loss:  0.598
# Total loss:  1.079 | PDE Loss:  -0.096 | Function Loss:  0.599
# Total loss:  1.078 | PDE Loss:  -0.097 | Function Loss:  0.6
# Total loss:  1.078 | PDE Loss:  -0.098 | Function Loss:  0.601
# Total loss:  1.078 | PDE Loss:  -0.099 | Function Loss:  0.601
# Total loss:  1.077 | PDE Loss:  -0.1 | Function Loss:  0.602
# Total loss:  1.077 | PDE Loss:  -0.101 | Function Loss:  0.603
# Total loss:  1.076 | PDE Loss:  -0.102 | Function Loss:  0.603
# Total loss:  1.075 | PDE Loss:  -0.104 | Function Loss:  0.606
# Total loss:  1.075 | PDE Loss:  -0.105 | Function Loss:  0.605
# Total loss:  1.074 | PDE Loss:  -0.106 | Function Loss:  0.605
# Total loss:  1.073 | PDE Loss:  -0.108 | Function Loss:  0.605
# Total loss:  1.071 | PDE Loss:  -0.11 | Function Loss:  0.604
# Total loss:  1.069 | PDE Loss:  -0.113 | Function Loss:  0.602
# Total loss:  1.065 | PDE Loss:  -0.116 | Function Loss:  0.597
# Total loss:  1.063 | PDE Loss:  -0.122 | Function Loss:  0.602
# Total loss:  1.057 | PDE Loss:  -0.124 | Function Loss:  0.589
# Total loss:  1.055 | PDE Loss:  -0.125 | Function Loss:  0.585
# Total loss:  1.051 | PDE Loss:  -0.126 | Function Loss:  0.577
# Total loss:  1.049 | PDE Loss:  -0.129 | Function Loss:  0.575
# Total loss:  1.048 | PDE Loss:  -0.129 | Function Loss:  0.572
# Total loss:  1.047 | PDE Loss:  -0.129 | Function Loss:  0.571
# Total loss:  1.046 | PDE Loss:  -0.129 | Function Loss:  0.568
# Total loss:  1.046 | PDE Loss:  -0.13 | Function Loss:  0.567
# Total loss:  1.045 | PDE Loss:  -0.13 | Function Loss:  0.565
# Total loss:  1.043 | PDE Loss:  -0.13 | Function Loss:  0.562
# Total loss:  1.042 | PDE Loss:  -0.13 | Function Loss:  0.557
# Total loss:  1.04 | PDE Loss:  -0.131 | Function Loss:  0.553
# Total loss:  1.039 | PDE Loss:  -0.131 | Function Loss:  0.548
# Total loss:  1.036 | PDE Loss:  -0.131 | Function Loss:  0.541
# Total loss:  1.033 | PDE Loss:  -0.131 | Function Loss:  0.531
# Total loss:  1.029 | PDE Loss:  -0.131 | Function Loss:  0.519
# Total loss:  1.025 | PDE Loss:  -0.132 | Function Loss:  0.507
# Total loss:  1.022 | PDE Loss:  -0.133 | Function Loss:  0.498
# Total loss:  1.018 | PDE Loss:  -0.134 | Function Loss:  0.488
# Total loss:  1.016 | PDE Loss:  -0.135 | Function Loss:  0.483
# Total loss:  1.014 | PDE Loss:  -0.136 | Function Loss:  0.479
# Total loss:  1.013 | PDE Loss:  -0.136 | Function Loss:  0.477
# Total loss:  1.012 | PDE Loss:  -0.137 | Function Loss:  0.476
# Total loss:  1.012 | PDE Loss:  -0.137 | Function Loss:  0.474
# Total loss:  1.01 | PDE Loss:  -0.138 | Function Loss:  0.471
# Total loss:  1.008 | PDE Loss:  -0.139 | Function Loss:  0.465
# Total loss:  1.005 | PDE Loss:  -0.14 | Function Loss:  0.459
# Total loss:  1.003 | PDE Loss:  -0.141 | Function Loss:  0.453
# Total loss:  1.0 | PDE Loss:  -0.142 | Function Loss:  0.446
# Total loss:  0.997 | PDE Loss:  -0.143 | Function Loss:  0.438
# Total loss:  0.996 | PDE Loss:  -0.143 | Function Loss:  0.434
# Total loss:  0.995 | PDE Loss:  -0.143 | Function Loss:  0.43
# Total loss:  0.994 | PDE Loss:  -0.143 | Function Loss:  0.427
# Total loss:  0.994 | PDE Loss:  -0.143 | Function Loss:  0.424
# Total loss:  0.993 | PDE Loss:  -0.143 | Function Loss:  0.423
# Total loss:  0.993 | PDE Loss:  -0.143 | Function Loss:  0.421
# Total loss:  0.992 | PDE Loss:  -0.143 | Function Loss:  0.419
# Total loss:  0.991 | PDE Loss:  -0.143 | Function Loss:  0.417
# Total loss:  0.991 | PDE Loss:  -0.143 | Function Loss:  0.415
# Total loss:  0.99 | PDE Loss:  -0.143 | Function Loss:  0.413
# Total loss:  0.99 | PDE Loss:  -0.143 | Function Loss:  0.412
# Total loss:  0.99 | PDE Loss:  -0.143 | Function Loss:  0.41
# Total loss:  0.989 | PDE Loss:  -0.143 | Function Loss:  0.409
# Total loss:  0.989 | PDE Loss:  -0.143 | Function Loss:  0.408
# Total loss:  0.989 | PDE Loss:  -0.143 | Function Loss:  0.407
# Total loss:  0.989 | PDE Loss:  -0.143 | Function Loss:  0.406
# Total loss:  0.989 | PDE Loss:  -0.143 | Function Loss:  0.405
# Total loss:  0.988 | PDE Loss:  -0.142 | Function Loss:  0.404
# Total loss:  0.988 | PDE Loss:  -0.142 | Function Loss:  0.402
# Total loss:  0.988 | PDE Loss:  -0.142 | Function Loss:  0.399
# Total loss:  0.987 | PDE Loss:  -0.141 | Function Loss:  0.396
# Total loss:  0.987 | PDE Loss:  -0.14 | Function Loss:  0.392
# Total loss:  0.987 | PDE Loss:  -0.14 | Function Loss:  0.388
# Total loss:  0.986 | PDE Loss:  -0.139 | Function Loss:  0.385
# Total loss:  0.986 | PDE Loss:  -0.139 | Function Loss:  0.382
# Total loss:  0.985 | PDE Loss:  -0.139 | Function Loss:  0.38
# Total loss:  0.985 | PDE Loss:  -0.139 | Function Loss:  0.379
# Total loss:  0.985 | PDE Loss:  -0.139 | Function Loss:  0.379
# Total loss:  0.985 | PDE Loss:  -0.139 | Function Loss:  0.378
# Total loss:  0.985 | PDE Loss:  -0.138 | Function Loss:  0.378
# Total loss:  0.985 | PDE Loss:  -0.138 | Function Loss:  0.376
# Total loss:  0.984 | PDE Loss:  -0.138 | Function Loss:  0.374
# Total loss:  0.984 | PDE Loss:  -0.138 | Function Loss:  0.371
# Total loss:  0.983 | PDE Loss:  -0.137 | Function Loss:  0.366
# Total loss:  0.982 | PDE Loss:  -0.136 | Function Loss:  0.359
# Total loss:  0.981 | PDE Loss:  -0.134 | Function Loss:  0.351
# Total loss:  0.981 | PDE Loss:  -0.133 | Function Loss:  0.343
# Total loss:  0.98 | PDE Loss:  -0.132 | Function Loss:  0.336
# Total loss:  0.978 | PDE Loss:  -0.133 | Function Loss:  0.33
# Total loss:  0.976 | PDE Loss:  -0.133 | Function Loss:  0.32
# Total loss:  0.975 | PDE Loss:  -0.134 | Function Loss:  0.319
# Total loss:  0.974 | PDE Loss:  -0.134 | Function Loss:  0.317
# Total loss:  0.972 | PDE Loss:  -0.136 | Function Loss:  0.312
# Total loss:  0.97 | PDE Loss:  -0.137 | Function Loss:  0.309
# Total loss:  0.968 | PDE Loss:  -0.139 | Function Loss:  0.304
# Total loss:  0.964 | PDE Loss:  -0.143 | Function Loss:  0.302
# Total loss:  0.958 | PDE Loss:  -0.149 | Function Loss:  0.3
# Total loss:  0.958 | PDE Loss:  -0.158 | Function Loss:  0.331
# Total loss:  0.955 | PDE Loss:  -0.154 | Function Loss:  0.302
# Total loss:  0.95 | PDE Loss:  -0.159 | Function Loss:  0.296
# Total loss:  0.956 | PDE Loss:  -0.172 | Function Loss:  0.363
# Total loss:  0.946 | PDE Loss:  -0.165 | Function Loss:  0.296
# Total loss:  0.939 | PDE Loss:  -0.171 | Function Loss:  0.29
# Total loss:  0.937 | PDE Loss:  -0.171 | Function Loss:  0.28
# Total loss:  0.935 | PDE Loss:  -0.173 | Function Loss:  0.277
# Total loss:  0.934 | PDE Loss:  -0.173 | Function Loss:  0.275
# Total loss:  0.933 | PDE Loss:  -0.176 | Function Loss:  0.278
# Total loss:  0.932 | PDE Loss:  -0.178 | Function Loss:  0.281
# Total loss:  0.93 | PDE Loss:  -0.18 | Function Loss:  0.281
# Total loss:  0.929 | PDE Loss:  -0.182 | Function Loss:  0.283
# Total loss:  0.927 | PDE Loss:  -0.184 | Function Loss:  0.281
# Total loss:  0.925 | PDE Loss:  -0.187 | Function Loss:  0.283
# Total loss:  0.924 | PDE Loss:  -0.187 | Function Loss:  0.277
# Total loss:  0.923 | PDE Loss:  -0.187 | Function Loss:  0.274
# Total loss:  0.922 | PDE Loss:  -0.187 | Function Loss:  0.266
# Total loss:  0.92 | PDE Loss:  -0.185 | Function Loss:  0.253
# Total loss:  0.92 | PDE Loss:  -0.183 | Function Loss:  0.244
# Total loss:  0.919 | PDE Loss:  -0.182 | Function Loss:  0.238
# Total loss:  0.919 | PDE Loss:  -0.181 | Function Loss:  0.233
# Total loss:  0.918 | PDE Loss:  -0.181 | Function Loss:  0.228
# Total loss:  0.918 | PDE Loss:  -0.181 | Function Loss:  0.228
# Total loss:  0.917 | PDE Loss:  -0.182 | Function Loss:  0.225
# Total loss:  0.916 | PDE Loss:  -0.182 | Function Loss:  0.223
# Total loss:  0.915 | PDE Loss:  -0.185 | Function Loss:  0.228
# Total loss:  0.914 | PDE Loss:  -0.187 | Function Loss:  0.228
# Total loss:  0.912 | PDE Loss:  -0.189 | Function Loss:  0.232
# Total loss:  0.91 | PDE Loss:  -0.193 | Function Loss:  0.236
# Total loss:  0.908 | PDE Loss:  -0.199 | Function Loss:  0.246
# Total loss:  0.906 | PDE Loss:  -0.202 | Function Loss:  0.249
# Total loss:  0.905 | PDE Loss:  -0.209 | Function Loss:  0.269
# Total loss:  0.905 | PDE Loss:  -0.206 | Function Loss:  0.257
# Total loss:  0.903 | PDE Loss:  -0.207 | Function Loss:  0.255
# Total loss:  0.901 | PDE Loss:  -0.209 | Function Loss:  0.253
# Total loss:  0.899 | PDE Loss:  -0.213 | Function Loss:  0.254
# Total loss:  0.896 | PDE Loss:  -0.216 | Function Loss:  0.253
# Total loss:  0.896 | PDE Loss:  -0.222 | Function Loss:  0.27
# Total loss:  0.895 | PDE Loss:  -0.22 | Function Loss:  0.26
# Total loss:  0.893 | PDE Loss:  -0.222 | Function Loss:  0.26
# Total loss:  0.891 | PDE Loss:  -0.224 | Function Loss:  0.258
# Total loss:  0.888 | PDE Loss:  -0.228 | Function Loss:  0.258
# Total loss:  0.885 | PDE Loss:  -0.232 | Function Loss:  0.256
# Total loss:  0.881 | PDE Loss:  -0.234 | Function Loss:  0.251
# Total loss:  0.881 | PDE Loss:  -0.241 | Function Loss:  0.272
# Total loss:  0.88 | PDE Loss:  -0.238 | Function Loss:  0.256
# Total loss:  0.877 | PDE Loss:  -0.244 | Function Loss:  0.263
# Total loss:  0.873 | PDE Loss:  -0.245 | Function Loss:  0.248
# Total loss:  0.869 | PDE Loss:  -0.248 | Function Loss:  0.24
# Total loss:  0.865 | PDE Loss:  -0.251 | Function Loss:  0.235
# Total loss:  0.862 | PDE Loss:  -0.254 | Function Loss:  0.236
# Total loss:  0.861 | PDE Loss:  -0.256 | Function Loss:  0.233
# Total loss:  0.86 | PDE Loss:  -0.256 | Function Loss:  0.231
# Total loss:  0.859 | PDE Loss:  -0.26 | Function Loss:  0.238
# Total loss:  0.857 | PDE Loss:  -0.259 | Function Loss:  0.228
# Total loss:  0.855 | PDE Loss:  -0.26 | Function Loss:  0.223
# Total loss:  0.854 | PDE Loss:  -0.261 | Function Loss:  0.22
# Total loss:  0.853 | PDE Loss:  -0.263 | Function Loss:  0.224
# ...
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.493
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.491
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.489
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.488
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.486
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.484
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.482
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.479
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.479
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.479
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.477
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.474
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.472
# Total loss:  0.216 | PDE Loss:  -0.793 | Function Loss:  -1.47
# Total loss:  0.216 | PDE Loss:  -0.794 | Function Loss:  -1.468
# Total loss:  0.216 | PDE Loss:  -0.794 | Function Loss:  -1.464
# Total loss:  0.216 | PDE Loss:  -0.794 | Function Loss:  -1.463
# Total loss:  0.216 | PDE Loss:  -0.794 | Function Loss:  -1.462
# Total loss:  0.216 | PDE Loss:  -0.794 | Function Loss:  -1.46
# Total loss:  0.215 | PDE Loss:  -0.794 | Function Loss:  -1.458
# Total loss:  0.215 | PDE Loss:  -0.794 | Function Loss:  -1.457
# Total loss:  0.215 | PDE Loss:  -0.794 | Function Loss:  -1.455
# Total loss:  0.215 | PDE Loss:  -0.794 | Function Loss:  -1.453
# Total loss:  0.215 | PDE Loss:  -0.794 | Function Loss:  -1.439
# Total loss:  0.215 | PDE Loss:  -0.794 | Function Loss:  -1.447
# Total loss:  0.215 | PDE Loss:  -0.794 | Function Loss:  -1.441
# Total loss:  0.215 | PDE Loss:  -0.795 | Function Loss:  -1.442
# Total loss:  0.215 | PDE Loss:  -0.795 | Function Loss:  -1.439
# Total loss:  0.215 | PDE Loss:  -0.796 | Function Loss:  -1.426
# Total loss:  0.215 | PDE Loss:  -0.796 | Function Loss:  -1.419
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.43
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.432
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.427
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.426
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.429
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.428
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.428
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.424
# Total loss:  0.214 | PDE Loss:  -0.796 | Function Loss:  -1.42
# Total loss:  0.214 | PDE Loss:  -0.797 | Function Loss:  -1.422
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.425
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.428
# Total loss:  0.214 | PDE Loss:  -0.797 | Function Loss:  -1.388
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.428
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.43
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.438
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.437
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.436
# Total loss:  0.213 | PDE Loss:  -0.797 | Function Loss:  -1.438
# Total loss:  0.212 | PDE Loss:  -0.797 | Function Loss:  -1.437
# Total loss:  0.212 | PDE Loss:  -0.797 | Function Loss:  -1.438
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.44
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.437
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.437
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.427
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.433
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.431
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.431
# Total loss:  0.212 | PDE Loss:  -0.798 | Function Loss:  -1.43
# Total loss:  0.212 | PDE Loss:  -0.799 | Function Loss:  -1.423
# Total loss:  0.212 | PDE Loss:  -0.799 | Function Loss:  -1.422
# Total loss:  0.212 | PDE Loss:  -0.799 | Function Loss:  -1.422
# Total loss:  0.212 | PDE Loss:  -0.799 | Function Loss:  -1.42
# Total loss:  0.211 | PDE Loss:  -0.799 | Function Loss:  -1.417
# Total loss:  0.211 | PDE Loss:  -0.799 | Function Loss:  -1.414
# Total loss:  0.211 | PDE Loss:  -0.799 | Function Loss:  -1.412
# Total loss:  0.211 | PDE Loss:  -0.799 | Function Loss:  -1.408
# Total loss:  0.211 | PDE Loss:  -0.799 | Function Loss:  -1.404
# Total loss:  0.211 | PDE Loss:  -0.8 | Function Loss:  -1.396
# Total loss:  0.211 | PDE Loss:  -0.8 | Function Loss:  -1.387
# Total loss:  0.211 | PDE Loss:  -0.8 | Function Loss:  -1.379
# Total loss:  0.211 | PDE Loss:  -0.8 | Function Loss:  -1.37
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.36
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.353
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.348
# Total loss:  0.211 | PDE Loss:  -0.802 | Function Loss:  -1.342
# Total loss:  0.211 | PDE Loss:  -0.802 | Function Loss:  -1.341
# Total loss:  0.211 | PDE Loss:  -0.802 | Function Loss:  -1.342
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.345
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.346
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.35
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.356
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.363
# Total loss:  0.211 | PDE Loss:  -0.801 | Function Loss:  -1.37
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.376
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.381
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.384
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.39
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.389
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.392
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.399
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.407
# Total loss:  0.21 | PDE Loss:  -0.801 | Function Loss:  -1.416
# Total loss:  0.209 | PDE Loss:  -0.801 | Function Loss:  -1.426
# Total loss:  0.209 | PDE Loss:  -0.801 | Function Loss:  -1.428
# Total loss:  0.209 | PDE Loss:  -0.801 | Function Loss:  -1.432
# Total loss:  0.209 | PDE Loss:  -0.801 | Function Loss:  -1.431
# Total loss:  0.209 | PDE Loss:  -0.801 | Function Loss:  -1.432
# Total loss:  0.209 | PDE Loss:  -0.801 | Function Loss:  -1.429
# Total loss:  0.209 | PDE Loss:  -0.802 | Function Loss:  -1.424
# Total loss:  0.208 | PDE Loss:  -0.802 | Function Loss:  -1.416
# Total loss:  0.208 | PDE Loss:  -0.802 | Function Loss:  -1.414
# Total loss:  0.208 | PDE Loss:  -0.803 | Function Loss:  -1.392
# Total loss:  0.208 | PDE Loss:  -0.802 | Function Loss:  -1.412
# Total loss:  0.208 | PDE Loss:  -0.803 | Function Loss:  -1.407
# Total loss:  0.208 | PDE Loss:  -0.803 | Function Loss:  -1.408
# Total loss:  0.208 | PDE Loss:  -0.803 | Function Loss:  -1.41
# Total loss:  0.208 | PDE Loss:  -0.803 | Function Loss:  -1.406
# Total loss:  0.208 | PDE Loss:  -0.803 | Function Loss:  -1.406
# Total loss:  0.207 | PDE Loss:  -0.803 | Function Loss:  -1.406
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.4
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.403
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.403
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.402
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.401
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.396
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.397
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.397
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.395
# Total loss:  0.207 | PDE Loss:  -0.804 | Function Loss:  -1.394
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.395
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.391
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.394
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.396
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.395
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.394
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.394
# Total loss:  0.206 | PDE Loss:  -0.805 | Function Loss:  -1.387
# Total loss:  0.206 | PDE Loss:  -0.806 | Function Loss:  -1.387
# Total loss:  0.206 | PDE Loss:  -0.806 | Function Loss:  -1.383
# Total loss:  0.206 | PDE Loss:  -0.806 | Function Loss:  -1.383
# Total loss:  0.205 | PDE Loss:  -0.806 | Function Loss:  -1.382
# Total loss:  0.205 | PDE Loss:  -0.806 | Function Loss:  -1.376
# Total loss:  0.205 | PDE Loss:  -0.806 | Function Loss:  -1.375
# Total loss:  0.205 | PDE Loss:  -0.806 | Function Loss:  -1.373
# Total loss:  0.205 | PDE Loss:  -0.806 | Function Loss:  -1.371
# Total loss:  0.205 | PDE Loss:  -0.806 | Function Loss:  -1.368
# Total loss:  0.205 | PDE Loss:  -0.806 | Function Loss:  -1.366
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.364
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.363
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.361
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.36
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.359
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.358
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.357
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.356
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.357
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.357
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.363
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.365
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.368
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.372
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.376
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.379
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.382
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.384
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.386
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.387
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.388
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.389
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.389
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.39
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.389
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.389
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.389
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.388
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.388
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.388
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.387
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.387
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.386
# Total loss:  0.205 | PDE Loss:  -0.807 | Function Loss:  -1.384
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.382
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.381
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.378
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.378
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.378
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.379
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.379
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.379
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.379
# Total loss:  0.204 | PDE Loss:  -0.807 | Function Loss:  -1.379
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.378
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.378
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.378
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.378
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.377
# Total loss:  0.204 | PDE Loss:  -0.808 | Function Loss:  -1.377
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.377
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.376
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.376
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.375
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.374
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.374
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.374
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.374
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.374
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.375
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.376
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.378
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.38
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.385
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.388
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.391
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.395
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.401
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.405
# Total loss:  0.203 | PDE Loss:  -0.808 | Function Loss:  -1.409
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.417
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.423
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.424
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.426
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.429
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.431
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.433
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.435
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.437
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.439
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.44
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.441
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.442
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.442
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.443
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.443
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.443
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.443
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.442
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.439
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.435
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.433
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.432
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.431
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.433
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.432
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.433
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Total loss:  0.202 | PDE Loss:  -0.808 | Function Loss:  -1.434
# Final Loss:  0.20175310969352722

# %%
pinn.plotting()
