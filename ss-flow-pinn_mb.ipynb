# %% [markdown]
# ## Physics Informed Neural Networks to Approximate Solution of PDEs

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
#from Common import NeuralNet, MultiVariatePoly
import time
torch.manual_seed(128)

# %% [markdown]
# Consider the porous 2D incompressible steady-state Stokes equation:
# $\newcommand{\Reynolds}{\text{Re}}\renewcommand{\div}{\text{div}}$
# $$
#  -\nabla \hat{p} + \div(\frac{2}{\Reynolds} \epsilon(\hat{u}))
#  -\frac{1}{\Reynolds} \left(\frac{5L^2}{2H_t^2} + \hat{\alpha}(\rho)\right) \hat{u} = 0
# $$
# $$
# \div(\hat{u})= 0
# $$
#
# with constant inflow and boundary conditions
# $$
# u_b(0,y) = \text{const} u_{in}
# $$
#
# $$
# u_b(x,0)=u_b(x,1)=0,
# $$
#
# We want to obtain an approximate solution of $u : [0,1]\times[0,1] \mapsto \mathbb{R}^2$ with physics informed neural networks (PINNs).
#
# To do so, we approximate the underlying solution with a feedforward dense neural network with tunable parameters $\theta$:
#
# $$
# u_\theta(x,y) \approx u(x,y)
# $$
# Define the following residuals:
#
#    - Interior residual given by,
#
#    $$r_{int,0,\theta}(x, y):= -\nabla \hat{p} + \div(\frac{2}{\Reynolds} \epsilon(\hat{u}))
#  -\frac{1}{\Reynolds} \left(\frac{5L^2}{2H_t^2} + \hat{\alpha}(\rho)\right) \hat{u}$$
#    $$r_{int,1,\theta}(x, y):= \div(\hat{u})$$
#
#    - inflow boundary residual given by,
#
#         $$r_{ib,\theta}(x,y):= u_{\theta}(x,y)- u_in$$
#
#    - outside boundary residual given by,
#
#         $$r_{ob,\theta}(x,0):= u_{\theta}(x,0), r_{ob, \theta}(x,1) := u_{\theta}(x,1) \quad \forall x \in [-1,1].$$
#
# and compute the corresponding loss functions:
#
# $$
# L_{int,0}(\theta) = \int_{[0,1]\times[0,1]}r_{int,0,\theta}^2(x, y) dxdy, \quad
# L_{int,1}(\theta) = \int_{[0,1]\times[0,1]}r_{int,1,\theta}^2(x, y) dxdy, \quad
# L_{ib}(\theta) = \int_{[0,1]}r_{ib,\theta}^2(0,y) dy, \quad
# L_{ob}(\theta) = \int_{[0,1]}r_{ob,\theta}^2(x,0) dx + \int_{[0,1]}r_{ob,\theta}^2(x,1) dx
# $$
#
# The loss functions include integrals that can be approximated by suitable quadrature rule. We use quasi Monte-Carlo and accordingly define the following training sets
#
# $$
# S_{int} =\{z_n\}, \quad 1 \leq n \leq N_{int},\quad z_n = (x,y)_n \in D_T,
# $$
#
# $$
# S_{ib} =\{y_n, u_b(0,y_n) \}, \quad1 \leq n \leq N_{ib}, y_n \in [0,1],
# $$
#
# $$
# S_{ob, 0}=\{x_n, u_0(x_n,0)\}\quad  1 \leq n \leq N_{ob}, x_n \in [0,1].
# $$
#
# $$
# S_{ob, 1}=\{x_n, u_0(x_n,1)\}\quad  1 \leq n \leq N_{ob}, x_n \in [0,1].
# $$
#
#
# with the training inputs points corresponding to low-discrepancy Sobol sequences.
#
# $$
# L_{int,0}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,1,\theta}^2(z_n) , \quad
# L_{int,1}(\theta) = \frac{1}{N_{int}}\sum_{i=1}^{N_{int}}r_{int,1,\theta}^2(z_n) , \quad
# L_{ib}(\theta) = \frac{1}{N_{ib}}\sum_{i=1}^{N_{ib}}r_{sb,\theta}^2(y_n,0)\quad
# L_{ob}(\theta) = \frac{1}{N_{ob}}\sum_{i=1}^{N_{ob}}r_{ob,\theta}^2(x_n,0) +\frac{1}{N_{ob}}\sum_{i=1}^{N_{ob}}r_{ob,\theta}^2(x_n,1)
# $$
#
# and solve the following minimization problem
#
# $$
# \theta^\ast = argmin_{\theta} \Big(L_{int}(\theta) + \lambda_u L_u(\theta)\Big)
# $$
#
# with
#
# $$
# L_{int} = L_{int,0} + L_{int,1}, \quad
# L_u = L_{ib}(\theta) + L_{ob}(\theta)
# $$

# %%
class NeuralNet(nn.Module):

    def __init__(self, input_dimension, output_dimension, n_hidden_layers, neurons, regularization_param, regularization_exp, retrain_seed):
        super(NeuralNet, self).__init__()
        # Number of input dimensions n
        self.input_dimension = input_dimension
        # Number of output dimensions m
        self.output_dimension = output_dimension
        # Number of neurons per layer
        self.neurons = neurons
        # Number of hidden layers
        self.n_hidden_layers = n_hidden_layers
        # Activation function
        self.activation = nn.Tanh()
        self.regularization_param = regularization_param
        # Regularization exponent
        self.regularization_exp = regularization_exp
        # Random seed for weight initialization

        self.input_layer = nn.Linear(self.input_dimension, self.neurons)
        self.hidden_layers = nn.ModuleList([nn.Linear(self.neurons, self.neurons) for _ in range(n_hidden_layers - 1)])
        self.output_layer = nn.Linear(self.neurons, self.output_dimension)
        self.retrain_seed = retrain_seed
        # Random Seed for weight initialization
        self.init_xavier()

    def forward(self, x):
        # The forward function performs the set of affine and non-linear transformations defining the network
        # (see equation above)
        x = self.activation(self.input_layer(x))
        for k, l in enumerate(self.hidden_layers):
            x = self.activation(l(x))
        return self.output_layer(x)

    def init_xavier(self):
        torch.manual_seed(self.retrain_seed)

        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                torch.nn.init.xavier_uniform_(m.weight, gain=g)
                # torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)

    def regularization(self):
        reg_loss = 0
        for name, param in self.named_parameters():
            if 'weight' in name:
                reg_loss = reg_loss + torch.norm(param, self.regularization_exp)
        return self.regularization_param * reg_loss


def fit(model, training_set, num_epochs, optimizer, p, verbose=True):
    history = list()

    # Loop over epochs
    for epoch in range(num_epochs):
        if verbose: print("################################ ", epoch, " ################################")

        running_loss = list([0])

        # Loop over batches
        for j, (x_train_, u_train_) in enumerate(training_set):
            def closure():
                # zero the parameter gradients
                optimizer.zero_grad()
                # forward + backward + optimize
                u_pred_ = model(x_train_)
                # Item 1. below
                loss = torch.mean((u_pred_.reshape(-1, ) - u_train_.reshape(-1, )) ** p) + model.regularization()
                # Item 2. below
                loss.backward()
                # Compute average training loss over batches for the current epoch
                running_loss[0] += loss.item()
                return loss

            # Item 3. below
            optimizer.step(closure=closure)

        if verbose: print('Loss: ', (running_loss[0] / len(training_set)))
        history.append(running_loss[0])

    return history

# %%
class Pinns:
    def __init__(self, n_int_, n_ib_, n_ob_):
        self.n_int = n_int_
        self.n_ib = n_ob_
        self.n_ob = n_ib_
        

        # Extrema of the solution domain (x,y) in [0,1]x[0,1]
        self.domain_extrema = torch.tensor([[0, 1],[0, 1]])

        # Number of space dimensions
        self.space_dimensions = 2

        # Parameter to balance role of data and PDE
        self.lambda_u = 10
        
        self.T_inlet = 293.15  # K

        self.channel_thickness = 380e-6  # m
        self.Ht = 0.5 * self.channel_thickness

        self.substrate_thickness = 150e-6  # m
        self.Hs = 0.5 * self.substrate_thickness

        self.conductivity_fluid = 0.598
        self.conductivity_substrate = 149
        self.viscosity_fluid = 1.004e-3
        self.capacity_fluid = 4180
        self.density_fluid = 998

        self.applied_pressure = 100000 * 5.0 / 4.0  # kg m^-1 s^-2
        self.L = 0.001  # m
        self.U = np.sqrt(self.applied_pressure / self.density_fluid)  # m/s


        self.nu = self.viscosity_fluid / self.density_fluid
        self.rho = self.load_rho()

        self.Re = self.L * self.U / self.nu
        #Prandtl_number = fd.Constant(capacity_fluid * viscosity_fluid / conductivity_fluid)
        self.nondim_Ht = self.Ht / self.L
        self.nondim_Hs = self.Hs / self.L
        
        self.qk = 1 #this change in each optimization steps
        self.alpha_f = 0
        self.alpha_s = 5*self.L**2/(2*self.Ht**2)

        # F Dense NN to approximate the solution of the underlying equation
        self.approximate_solution = NeuralNet(input_dimension=self.domain_extrema.shape[0], output_dimension=3,
                                              n_hidden_layers=10,
                                              neurons=20,
                                              regularization_param=0.,
                                              regularization_exp=2.,
                                              retrain_seed=42)
        '''self.approximate_solution = MultiVariatePoly(self.domain_extrema.shape[0], 3)'''

        # Generator of Sobol sequences
        self.soboleng = torch.quasirandom.SobolEngine(dimension=self.domain_extrema.shape[0])
                

        # Training sets S_ib, S_ob, S_int as torch dataloader
        self.training_set_ib, self.training_set_ob, self.training_set_int, self.training_set_pb = self.assemble_datasets()
    
    def load_rho(self):
        #file_path = "/home/team/CAMLab-DLSCTutorials/"
        file_path = "C:\\Users\\bonvi\\Documents\\simulation_hack\\simulation_hackaton_eth-rafael\\simulation_hackaton_eth-rafael\\formatted_data0\\"
        file = file_path + 'results-0.h5_rhof.out'
        #rho = np.zeros((100,100))
        #rho[:,30:80] = np.full(rho[:, 30:80].shape, 1)
        return np.loadtxt(file)

    ################################################################################################
    # Function to linearly transform a tensor whose value are between 0 and 1
    # to a tensor whose values are between the domain extrema
    def convert(self, tens):
        assert (tens.shape[1] == self.domain_extrema.shape[0])
        return tens * (self.domain_extrema[:, 1] - self.domain_extrema[:, 0]) + self.domain_extrema[:, 0]

    # Initial condition to solve the inflow boundary condition
    def initial_condition(self, x):
        return np.array([1,0])


    ################################################################################################
    # Function returning the input-output tensor required to assemble the training set S_ib corresponding to the vertical boundary
    def add_inflow_boundary_points(self):
        #y0 = self.domain_extrema[0,1]
        input_ib = self.convert(self.soboleng.draw(self.n_ib))
        input_ib[:, 0] = torch.full(input_ib[:, 0].shape, 0)
#         output_ib = self.initial_condition(input_ib[:, 1]).reshape(-1, 1)  # reshape to [64, 1]
        output_ib = torch.clone(input_ib)
        output_ib[:,0] = torch.full(output_ib[:,0].shape,1)
        output_ib[:,1] = torch.full(output_ib[:,1].shape,0)
    
#         output_ib = self.initial_condition(input_ib[:, 1]).reshape(-1, 1)
        #print("Shape of input_ib[:, 1]:", input_ib[:, 1].shape)
        #print("Shape of output_ib:", output_ib.shape)


        return input_ib, output_ib

    # Function returning the input-output tensor required to assemble the training set S_ob corresponding to the horizontal boundary
    def add_horizontal_boundary_points(self):

        input_ob = self.convert(self.soboleng.draw(self.n_ob))

        input_ob_0 = torch.clone(input_ob)
        input_ob_0[:, 1] = torch.full(input_ob_0[:, 1].shape, 0)

        input_ob_L = torch.clone(input_ob)
        input_ob_L[:, 1] = torch.full(input_ob_L[:, 1].shape, 1)

        output_ob_0 = torch.clone(input_ob)
        output_ob_0[:, 0] = torch.full(output_ob_0[:, 0].shape, 0)
        output_ob_0[:, 1] = torch.full(output_ob_0[:, 1].shape, 0)
        output_ob_L = torch.clone(input_ob)
        output_ob_L[:, 0] = torch.full(output_ob_L[:, 0].shape, 0)
        output_ob_L[:, 1] = torch.full(output_ob_L[:, 1].shape, 0)

        return torch.cat([input_ob_0, input_ob_L], 0), torch.cat([output_ob_0, output_ob_L], 0)
    
    def add_p_points(self):
        input_ib_p = self.convert(self.soboleng.draw(self.n_ob))
        input_ob_0_p = torch.clone(input_ib_p)
        input_ob_0_p[:, 0] = torch.full(input_ob_0_p[:, 0].shape, 1)
        output_ob_0_p = torch.clone(input_ib_p)[:,0]
        output_ob_0_p = torch.full(output_ob_0_p.shape, 0)
        #output_ob_0_p[:, 1] = torch.full(output_ob_0_p[:, 1].shape, 0)
        return input_ib_p, output_ob_0_p
        
    #  Function returning the input-output tensor required to assemble the training set S_int corresponding to the interior domain where the PDE is enforced
    def add_interior_points(self):
        input_int = self.convert(self.soboleng.draw(self.n_int))
        output_int = torch.zeros((input_int.shape[0], 1))
        return input_int, output_int
    

    # Function returning the training sets S_ib, S_ob, S_int as dataloader
    def assemble_datasets(self):
        input_ib, output_ib = self.add_inflow_boundary_points()  # S_ib
        input_ob, output_ob = self.add_horizontal_boundary_points()   # S_ob
        input_int, output_int = self.add_interior_points()         # S_int
        input_pb, output_pb =self.add_p_points()

#         training_set_ib = DataLoader(torch.utils.data.TensorDataset(input_ib, output_ib), shuffle=False)
#         training_set_ob = DataLoader(torch.utils.data.TensorDataset(input_ob, output_ob), shuffle=False)
#         training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), shuffle=False)
        training_set_ib = DataLoader(torch.utils.data.TensorDataset(input_ib, output_ib), batch_size=self.n_ib, shuffle=False)
        training_set_ob = DataLoader(torch.utils.data.TensorDataset(input_ob, output_ob), batch_size=2*self.n_ob, shuffle=False)
        training_set_int = DataLoader(torch.utils.data.TensorDataset(input_int, output_int), batch_size=self.n_int, shuffle=False)
        training_set_p = DataLoader(torch.utils.data.TensorDataset(input_pb, output_pb), batch_size=self.n_int, shuffle=False)
        return training_set_ib, training_set_ob, training_set_int, training_set_p

    ################################################################################################
    # Function to compute the terms required in the definition of the INFLOW boundary residual
    def apply_inflow_condition(self, input_ib):
        u_pred_ib = self.approximate_solution(input_ib)#[:,0:2]
        return u_pred_ib

    # Function to compute the terms required in the definition of the HORIZONTAL boundary residual
    def apply_boundary_conditions(self, input_ob):
        u_pred_ob = self.approximate_solution(input_ob)#[:,0:2]

        return u_pred_ob

    def alpha(self,rho):
        return (1-rho)/(1+self.qk*rho)*(self.alpha_s - self.alpha_f)+self.alpha_f
    
    def interpolate_rho(self,input_int):
        input_int = (input_int.detach().numpy() * 100).astype(int)
        rho = np.zeros((input_int.shape[0],1))
        for i in range(input_int.shape[0]):
            x = input_int[i,0]
            y = input_int[i,1]
            rho[i] = self.rho[x,y]
        return torch.Tensor(rho)
        
    def compute_pde_residual(self, input_int):
        rho = self.interpolate_rho(input_int)
        input_int.requires_grad = True # save gradients
        
        u = self.approximate_solution(input_int)[:,0:2]
        p = self.approximate_solution(input_int)[:,2] 

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 + u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        #print(grad_u[0].shape)
        #grad_u = grad_u[0]
        grad_u_x = grad_u[:, 0]
        grad_u_y = grad_u[:, 1]
        #grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 0]
        #grad_u_xx_y = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0][:, 1]
        #grad_u_yy = torch.autograd.grad(grad_u_y.sum(), input_int, create_graph=True)[0][:, 1]
        #grad_u_yy_x = torch.autograd.grad(grad_u_y.sum(), input_int, create_graph=True)[0][:, 0]
        grad_u_xx = torch.autograd.grad(grad_u_x.sum(), input_int, create_graph=True)[0]
        grad_u_yy = torch.autograd.grad(grad_u_y.sum(), input_int, create_graph=True)[0]


        grad_p = torch.autograd.grad(p.sum(), input_int, create_graph=True)[0]

        
        nabla_p = grad_p
        #div_term = 2*self.Re*(torch.concat((grad_u_xx + grad_u_yy_x, grad_u_xx_y + grad_u_yy))).reshape(-1,2)
        div_term = 2*self.Re*(torch.concat((torch.sum(grad_u_xx, dim=1),torch.sum(grad_u_yy, dim =1)))).reshape(-1,2)
        drag_term = 1/self.Re * (5 * self.L**2 / (2 * self.Ht**2) + self.alpha(rho)) * u
        
        residual = -nabla_p + div_term - drag_term
        return residual.reshape(-1, )
    
    
    # Function to compute the incompressibility term residuals on the interior
    def compute_incompress_residual(self, input_int):
        input_int.requires_grad = True
        u = self.approximate_solution(input_int)[:,0:2]

        # grad compute the gradient of a "SCALAR" function L with respect to some input nxm TENSOR Z=[[x1, y1],[x2,y2],[x3,y3],...,[xn,yn]], m=2
        # it returns grad_L = [[dL/dx1, dL/dy1],[dL/dx2, dL/dy2],[dL/dx3, dL/dy3],...,[dL/dxn, dL/dyn]]
        # Note: pytorch considers a tensor [u1, u2,u3, ... ,un] a vectorial function
        # whereas sum_u = u1 + u2 + u3 + u4 + ... + un as a "scalar" one

        # In our case ui = u(xi), therefore the line below returns:
        # grad_u = [[dsum_u/dx1, dsum_u/dy1],[dsum_u/dx2, dsum_u/dy2],[dsum_u/dx3, dL/dy3],...,[dsum_u/dxm, dsum_u/dyn]]
        # and dsum_u/dxi = d(u1 + u2 + u3 + u4 + ... + un)/dxi = d(u(x1) + u(x2) u3(x3) + u4(x4) + ... + u(xn))/dxi = dui/dxi
        
        grad_u = torch.autograd.grad(u.sum(), input_int, create_graph=True)[0]
        grad_u_x = grad_u[:, 0]
        grad_u_y = grad_u[:, 1]
        div_u = grad_u_x + grad_u_y
    
        return div_u.reshape(-1, )

    # Function to compute the total loss (weighted sum of inflow boundary loss, horizontal boundary loss and interior loss)
    def compute_loss(self, inp_train_ib, u_train_ib, inp_train_ob, u_train_ob, inp_train_int,inp_train_pb, u_train_pb, verbose=True):
        u_pred_ib = self.apply_inflow_condition(inp_train_ib)[:,0:2]
        u_pred_ob = self.apply_boundary_conditions(inp_train_ob)[:,0:2]
        p_pred_ib = self.apply_inflow_condition(inp_train_ib)[:,2:3]
        p_pred_pb = self.apply_inflow_condition(inp_train_pb)[:,2:3]
        #p_pred_ob = self.apply_boundary_condition(inp_train_ob)[:,2:4]
        
#         print("Shape of u_pred_ib", u_pred_ib.shape)
#         print("Shape of u_train_ib:", u_train_ib.shape)
        #print("Shape of u_pred_ob", u_pred_ob.shape)
        #print("Shape of u_train_ob:", u_train_ob.shape)
        


        assert (u_pred_ib.shape[1] == u_train_ib.shape[1])
        assert (u_pred_ob.shape[1] == u_train_ob.shape[1])
        #assert (p_pred_ib.shape[1] == u_train_ib.shape[1])
        #assert (p_pred_ob.shape[1] == u_train_ob.shape[1])

        r_int = self.compute_pde_residual(inp_train_int)
        r_inc = self.compute_incompress_residual(inp_train_int)
        r_ib = u_train_ib - u_pred_ib
        r_ob = u_train_ob - u_pred_ob
        r_ib_p = u_train_ib - p_pred_ib
        r_pb = u_train_pb - p_pred_pb
        #r_ob_p = u_train_ob - p_pred_ob

        loss_ib = torch.mean(abs(r_ib) ** 2)
        loss_ob = torch.mean(abs(r_ob) ** 2)
        loss_ib_p = torch.mean(abs(r_ib_p) ** 2)
        loss_pb = torch.mean(abs(r_pb) **2)
        #loss_ob_p = torch.mean(abs(r_ob_p) ** 2)
        loss_int = torch.mean(abs(r_int) ** 2)
        loss_inc = torch.mean(abs(r_inc) ** 2)

        loss_u =  loss_ib + 10*loss_ob
        loss_p = loss_ib_p + loss_pb#+ loss_ob_p

        loss = torch.log10(self.lambda_u * (loss_u+ loss_p)  + loss_int + loss_inc/10)
        #loss = loss_u  + loss_p
        if verbose: print("Total loss: ", round(loss.item(), 4), "| PDE Loss: ", round(torch.log10(loss_u).item(), 4), "| Function Loss: ", round(torch.log10(loss_int + loss_inc).item(), 4))

        return loss

    ################################################################################################
    def fit(self, num_epochs, optimizer, verbose=True):
        history = list()

        # Loop over epochs
        for epoch in range(num_epochs):
            if verbose: print("################################ ", epoch, " ################################")

            for j, ((inp_train_ib, u_train_ib), (inp_train_ob, u_train_ob), (inp_train_int, u_train_int), (inp_train_pb, u_train_pb)) in enumerate(zip(self.training_set_ib, self.training_set_ob, self.training_set_int, self.training_set_pb)):
                def closure():
                    optimizer.zero_grad()
                    loss = self.compute_loss(inp_train_ib, u_train_ib, inp_train_ob, u_train_ob, inp_train_int, inp_train_pb, u_train_pb, verbose=verbose)
                    loss.backward()

                    history.append(loss.item())
                    return loss

                optimizer.step(closure=closure)

        print('Final Loss: ', history[-1])

        return history

    ################################################################################################
    def plotting(self):
        inputs = self.soboleng.draw(100000)
        #inputs = self.convert(inputs)

        output_ux = self.approximate_solution(inputs)[:,0].reshape(-1, )
        output_uy = self.approximate_solution(inputs)[:,1].reshape(-1, )
        output_px = self.approximate_solution(inputs)[:,2].reshape(-1, )
        #output_py = self.approximate_solution(inputs)[:,3].reshape(-1, )
#         exact_output = self.exact_solution(inputs).reshape(-1, )

        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].tripcolor(inputs[:, 0].detach(), inputs[:, 1].detach(), output_ux.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        im2 = axs[1].tripcolor(inputs[:, 0].detach(), inputs[:, 1].detach(), output_uy.detach(), cmap="jet")
        axs[1].set_xlabel("x")
        axs[1].set_ylabel("t")
        plt.colorbar(im2, ax=axs[1])
        axs[1].grid(True, which="both", ls=":")
        axs[1].set_title("u_y")
        axs[0].set_title("u_x")

        plt.show()
        
        fig, axs = plt.subplots(1, 2, figsize=(16, 8), dpi=150)
        im1 = axs[0].tripcolor(inputs[:, 0].detach(), inputs[:, 1].detach(), output_px.detach(), cmap="jet")
        axs[0].set_xlabel("x")
        axs[0].set_ylabel("t")
        plt.colorbar(im1, ax=axs[0])
        axs[0].grid(True, which="both", ls=":")
        #im2 = axs[1].tripcolor(inputs[:, 0].detach(), inputs[:, 1].detach(), output_py.detach(), cmap="jet")
    
        axs[0].set_title("p")

        plt.show()

#         err = (torch.mean((output - exact_output) ** 2) / torch.mean(exact_output ** 2)) ** 0.5 * 100
#         print("L2 Relative Error Norm: ", err.item(), "%")

# %%
# Solve the heat equation:
# u_t = u_xx, (t,x) in [0, 0.1]x[-1,1]
# with zero dirichlet BC and
# u(x,0)= -sin(pi x)

n_int = 256
n_sb = 64
n_tb = 64

pinn = Pinns(n_int, n_sb, n_tb)

# %%
# Plot the input training points
input_ib_, output_ib_ = pinn.add_inflow_boundary_points()
input_ob_, output_ob_ = pinn.add_horizontal_boundary_points()
input_int_, output_int_ = pinn.add_interior_points()

plt.figure(figsize=(16, 8), dpi=150)
plt.scatter(input_ob_[:, 0].detach().numpy(), input_ob_[:, 1].detach().numpy(), label="Boundary Points")
plt.scatter(input_int_[:, 0].detach().numpy(), input_int_[:, 1].detach().numpy(), label="Interior Points")
plt.scatter(input_ib_[:, 0].detach().numpy(), input_ib_[:, 1].detach().numpy(), label="Initial Points")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
n_epochs = 1
optimizer_LBFGS = optim.LBFGS(pinn.approximate_solution.parameters(),
                              lr=float(0.5),
                              max_iter=50000,
                              max_eval=50000,
                              history_size=150,
                              line_search_fn="strong_wolfe",
                              tolerance_change=1.0 * np.finfo(float).eps)
optimizer_ADAM = optim.Adam(pinn.approximate_solution.parameters(),
                            lr=float(0.001))

# %%
hist = pinn.fit(num_epochs=n_epochs,
                optimizer=optimizer_LBFGS,
                verbose=True)

plt.figure(dpi=150)
plt.grid(True, which="both", ls=":")
plt.plot(np.arange(1, len(hist) + 1), hist, label="Train Loss")
plt.xscale("log")
plt.legend()
# Out:
# ################################  0  ################################
# Total loss:  12.3033 | PDE Loss:  0.0487 | Function Loss:  12.3033
# Total loss:  12.1056 | PDE Loss:  0.1729 | Function Loss:  12.1056
# Total loss:  11.7247 | PDE Loss:  0.2776 | Function Loss:  11.7247
# Total loss:  11.6148 | PDE Loss:  0.3355 | Function Loss:  11.6148
# Total loss:  11.3887 | PDE Loss:  0.4389 | Function Loss:  11.3887
# Total loss:  11.209 | PDE Loss:  0.4772 | Function Loss:  11.209
# Total loss:  10.7226 | PDE Loss:  0.6286 | Function Loss:  10.7226
# Total loss:  10.3878 | PDE Loss:  0.7879 | Function Loss:  10.3878
# Total loss:  9.1199 | PDE Loss:  1.0322 | Function Loss:  9.1199
# Total loss:  8.0547 | PDE Loss:  1.0615 | Function Loss:  8.0547
# Total loss:  7.428 | PDE Loss:  1.0218 | Function Loss:  7.428
# Total loss:  6.5176 | PDE Loss:  0.5988 | Function Loss:  6.5175
# Total loss:  5.8997 | PDE Loss:  0.4214 | Function Loss:  5.8997
# Total loss:  5.6924 | PDE Loss:  0.2149 | Function Loss:  5.6923
# Total loss:  5.133 | PDE Loss:  -0.211 | Function Loss:  5.1325
# Total loss:  4.9244 | PDE Loss:  -0.2256 | Function Loss:  4.9237
# Total loss:  5.9357 | PDE Loss:  -0.1213 | Function Loss:  5.9356
# Total loss:  4.7064 | PDE Loss:  -0.2089 | Function Loss:  4.7053
# Total loss:  4.5742 | PDE Loss:  -0.2183 | Function Loss:  4.5726
# Total loss:  4.3508 | PDE Loss:  -0.1173 | Function Loss:  4.3481
# Total loss:  4.2179 | PDE Loss:  -0.0861 | Function Loss:  4.2142
# Total loss:  4.0952 | PDE Loss:  -0.0031 | Function Loss:  4.0905
# Total loss:  4.0566 | PDE Loss:  0.0629 | Function Loss:  4.0514
# Total loss:  3.9459 | PDE Loss:  -0.0223 | Function Loss:  3.9391
# Total loss:  3.8149 | PDE Loss:  -0.0542 | Function Loss:  3.8056
# Total loss:  3.5742 | PDE Loss:  -0.1065 | Function Loss:  3.5574
# Total loss:  3.4302 | PDE Loss:  -0.1264 | Function Loss:  3.4055
# Total loss:  3.2978 | PDE Loss:  -0.1077 | Function Loss:  3.2631
# Total loss:  3.233 | PDE Loss:  0.1937 | Function Loss:  3.1851
# Total loss:  2.9825 | PDE Loss:  0.1415 | Function Loss:  2.8954
# Total loss:  2.8679 | PDE Loss:  0.0663 | Function Loss:  2.7552
# Total loss:  2.8014 | PDE Loss:  0.1067 | Function Loss:  2.664
# Total loss:  2.7489 | PDE Loss:  0.1371 | Function Loss:  2.5876
# Total loss:  2.7007 | PDE Loss:  0.1419 | Function Loss:  2.5157
# Total loss:  2.5536 | PDE Loss:  0.1566 | Function Loss:  2.2622
# Total loss:  2.4598 | PDE Loss:  0.183 | Function Loss:  2.0486
# Total loss:  2.3697 | PDE Loss:  0.2252 | Function Loss:  1.7505
# Total loss:  2.3354 | PDE Loss:  0.252 | Function Loss:  1.567
# Total loss:  2.3144 | PDE Loss:  0.2677 | Function Loss:  1.4145
# Total loss:  2.3043 | PDE Loss:  0.2885 | Function Loss:  1.3043
# Total loss:  2.2985 | PDE Loss:  0.3012 | Function Loss:  1.2294
# Total loss:  2.2938 | PDE Loss:  0.3159 | Function Loss:  1.1561
# Total loss:  2.2895 | PDE Loss:  0.3306 | Function Loss:  1.0822
# Total loss:  2.2856 | PDE Loss:  0.3455 | Function Loss:  1.0111
# Total loss:  2.2817 | PDE Loss:  0.3601 | Function Loss:  0.9435
# Total loss:  2.2767 | PDE Loss:  0.3765 | Function Loss:  0.8721
# Total loss:  2.265 | PDE Loss:  0.393 | Function Loss:  0.7847
# Total loss:  2.2372 | PDE Loss:  0.4407 | Function Loss:  1.2884
# Total loss:  2.2075 | PDE Loss:  0.4207 | Function Loss:  1.1552
# Total loss:  2.1563 | PDE Loss:  0.3718 | Function Loss:  1.0847
# Total loss:  2.1168 | PDE Loss:  0.3162 | Function Loss:  0.9547
# Total loss:  2.0982 | PDE Loss:  0.181 | Function Loss:  1.5643
# Total loss:  2.0745 | PDE Loss:  0.2303 | Function Loss:  1.2679
# Total loss:  2.0276 | PDE Loss:  0.0847 | Function Loss:  1.2881
# Total loss:  1.9794 | PDE Loss:  0.0785 | Function Loss:  0.8003
# Total loss:  1.9363 | PDE Loss:  0.0842 | Function Loss:  0.6004
# Total loss:  1.8731 | PDE Loss:  0.0351 | Function Loss:  0.7807
# Total loss:  1.7754 | PDE Loss:  -0.0583 | Function Loss:  1.3258
# Total loss:  1.6827 | PDE Loss:  -0.0362 | Function Loss:  1.153
# Total loss:  1.5203 | PDE Loss:  -0.0599 | Function Loss:  0.8442
# Total loss:  1.3002 | PDE Loss:  -0.1452 | Function Loss:  0.815
# Total loss:  1.8664 | PDE Loss:  -0.2123 | Function Loss:  1.7701
# Total loss:  1.2527 | PDE Loss:  -0.1556 | Function Loss:  0.637
# Total loss:  1.1762 | PDE Loss:  -0.1424 | Function Loss:  0.2441
# Total loss:  1.1311 | PDE Loss:  -0.1445 | Function Loss:  0.1679
# Total loss:  1.0982 | PDE Loss:  -0.1521 | Function Loss:  0.1388
# Total loss:  1.0676 | PDE Loss:  -0.1658 | Function Loss:  0.0218
# Total loss:  1.043 | PDE Loss:  -0.1793 | Function Loss:  -0.145
# Total loss:  1.024 | PDE Loss:  -0.1949 | Function Loss:  -0.3214
# Total loss:  1.0096 | PDE Loss:  -0.2089 | Function Loss:  -0.4831
# Total loss:  0.9993 | PDE Loss:  -0.2225 | Function Loss:  -0.5372
# Total loss:  0.9805 | PDE Loss:  -0.2502 | Function Loss:  -0.6464
# Total loss:  0.9465 | PDE Loss:  -0.3056 | Function Loss:  -0.9675
# Total loss:  0.9359 | PDE Loss:  -0.3192 | Function Loss:  -1.2338
# Total loss:  0.932 | PDE Loss:  -0.3231 | Function Loss:  -1.2136
# Total loss:  0.9279 | PDE Loss:  -0.3279 | Function Loss:  -1.1972
# Total loss:  0.9247 | PDE Loss:  -0.3337 | Function Loss:  -1.1769
# Total loss:  0.9225 | PDE Loss:  -0.3379 | Function Loss:  -1.1707
# Total loss:  0.9202 | PDE Loss:  -0.3412 | Function Loss:  -1.2401
# Total loss:  0.9182 | PDE Loss:  -0.3429 | Function Loss:  -1.4045
# Total loss:  0.9174 | PDE Loss:  -0.3433 | Function Loss:  -1.5262
# Total loss:  0.9172 | PDE Loss:  -0.3434 | Function Loss:  -1.5734
# Total loss:  0.9172 | PDE Loss:  -0.3434 | Function Loss:  -1.5877
# Total loss:  0.9171 | PDE Loss:  -0.3434 | Function Loss:  -1.5922
# Total loss:  0.9171 | PDE Loss:  -0.3434 | Function Loss:  -1.5941
# Total loss:  0.9171 | PDE Loss:  -0.3434 | Function Loss:  -1.5958
# Total loss:  0.9171 | PDE Loss:  -0.3434 | Function Loss:  -1.598
# Total loss:  0.9171 | PDE Loss:  -0.3434 | Function Loss:  -1.6018
# Total loss:  0.9171 | PDE Loss:  -0.3434 | Function Loss:  -1.6085
# Total loss:  0.917 | PDE Loss:  -0.3434 | Function Loss:  -1.62
# Total loss:  0.9169 | PDE Loss:  -0.3433 | Function Loss:  -1.6384
# Total loss:  0.9168 | PDE Loss:  -0.3433 | Function Loss:  -1.6639
# Total loss:  0.9167 | PDE Loss:  -0.3433 | Function Loss:  -1.6944
# Total loss:  0.9166 | PDE Loss:  -0.3434 | Function Loss:  -1.7298
# Total loss:  0.9164 | PDE Loss:  -0.3434 | Function Loss:  -1.7771
# Total loss:  0.9162 | PDE Loss:  -0.3434 | Function Loss:  -1.834
# Total loss:  0.9161 | PDE Loss:  -0.3434 | Function Loss:  -1.8747
# Total loss:  0.9161 | PDE Loss:  -0.3434 | Function Loss:  -1.9005
# Total loss:  0.916 | PDE Loss:  -0.3434 | Function Loss:  -1.9185
# Total loss:  0.916 | PDE Loss:  -0.3434 | Function Loss:  -1.9315
# Total loss:  0.916 | PDE Loss:  -0.3434 | Function Loss:  -1.945
# Total loss:  0.9159 | PDE Loss:  -0.3434 | Function Loss:  -1.9508
# Total loss:  0.9158 | PDE Loss:  -0.3435 | Function Loss:  -1.9495
# Total loss:  0.9158 | PDE Loss:  -0.3435 | Function Loss:  -1.956
# Total loss:  0.9158 | PDE Loss:  -0.3435 | Function Loss:  -1.9541
# Total loss:  0.9158 | PDE Loss:  -0.3435 | Function Loss:  -1.9623
# Total loss:  0.9158 | PDE Loss:  -0.3435 | Function Loss:  -1.9674
# Total loss:  0.9158 | PDE Loss:  -0.3435 | Function Loss:  -1.9753
# Total loss:  0.9158 | PDE Loss:  -0.3435 | Function Loss:  -1.9871
# Total loss:  0.9157 | PDE Loss:  -0.3435 | Function Loss:  -2.0012
# Total loss:  0.9157 | PDE Loss:  -0.3435 | Function Loss:  -2.0169
# Total loss:  0.9157 | PDE Loss:  -0.3435 | Function Loss:  -2.031
# Total loss:  0.9156 | PDE Loss:  -0.3435 | Function Loss:  -2.0372
# Total loss:  0.9156 | PDE Loss:  -0.3435 | Function Loss:  -2.0279
# Total loss:  0.9155 | PDE Loss:  -0.3435 | Function Loss:  -2.0076
# Total loss:  0.9154 | PDE Loss:  -0.3436 | Function Loss:  -1.9845
# Total loss:  0.9154 | PDE Loss:  -0.3436 | Function Loss:  -1.9603
# Total loss:  0.9154 | PDE Loss:  -0.3436 | Function Loss:  -1.9409
# Total loss:  0.9153 | PDE Loss:  -0.3436 | Function Loss:  -1.9175
# Total loss:  0.9153 | PDE Loss:  -0.3436 | Function Loss:  -1.9026
# Total loss:  0.9153 | PDE Loss:  -0.3436 | Function Loss:  -1.8745
# Total loss:  0.9153 | PDE Loss:  -0.3436 | Function Loss:  -1.8602
# Total loss:  0.9153 | PDE Loss:  -0.3436 | Function Loss:  -1.841
# Total loss:  0.9153 | PDE Loss:  -0.3436 | Function Loss:  -1.8159
# Total loss:  0.9153 | PDE Loss:  -0.3437 | Function Loss:  -1.7804
# Total loss:  0.9152 | PDE Loss:  -0.3437 | Function Loss:  -1.7275
# Total loss:  0.9151 | PDE Loss:  -0.3438 | Function Loss:  -1.6437
# Total loss:  0.915 | PDE Loss:  -0.3439 | Function Loss:  -1.4915
# Total loss:  0.9155 | PDE Loss:  -0.3444 | Function Loss:  -1.0957
# Total loss:  0.9147 | PDE Loss:  -0.3442 | Function Loss:  -1.337
# Total loss:  0.9144 | PDE Loss:  -0.3444 | Function Loss:  -1.2585
# Total loss:  0.9137 | PDE Loss:  -0.3447 | Function Loss:  -1.2056
# Total loss:  0.9127 | PDE Loss:  -0.3453 | Function Loss:  -1.1085
# Total loss:  0.9412 | PDE Loss:  -0.3463 | Function Loss:  -0.1684
# Total loss:  0.9124 | PDE Loss:  -0.3455 | Function Loss:  -1.0694
# Total loss:  0.9138 | PDE Loss:  -0.3455 | Function Loss:  -0.9092
# Total loss:  0.9115 | PDE Loss:  -0.3456 | Function Loss:  -1.1247
# Total loss:  0.911 | PDE Loss:  -0.3457 | Function Loss:  -1.2126
# Total loss:  0.9107 | PDE Loss:  -0.3458 | Function Loss:  -1.2409
# Total loss:  0.9104 | PDE Loss:  -0.3459 | Function Loss:  -1.2336
# Total loss:  0.9102 | PDE Loss:  -0.346 | Function Loss:  -1.2197
# Total loss:  0.91 | PDE Loss:  -0.3461 | Function Loss:  -1.2157
# Total loss:  0.9099 | PDE Loss:  -0.3462 | Function Loss:  -1.2011
# Total loss:  0.9098 | PDE Loss:  -0.3463 | Function Loss:  -1.1904
# Total loss:  0.9098 | PDE Loss:  -0.3464 | Function Loss:  -1.1816
# Total loss:  0.9098 | PDE Loss:  -0.3464 | Function Loss:  -1.1701
# Total loss:  0.9097 | PDE Loss:  -0.3465 | Function Loss:  -1.1609
# Total loss:  0.9096 | PDE Loss:  -0.3466 | Function Loss:  -1.1406
# Total loss:  0.9094 | PDE Loss:  -0.3468 | Function Loss:  -1.1172
# Total loss:  0.9092 | PDE Loss:  -0.347 | Function Loss:  -1.0807
# Total loss:  0.9089 | PDE Loss:  -0.3472 | Function Loss:  -1.0789
# Total loss:  0.9086 | PDE Loss:  -0.3472 | Function Loss:  -1.0939
# Total loss:  0.9083 | PDE Loss:  -0.3473 | Function Loss:  -1.0806
# Total loss:  0.9081 | PDE Loss:  -0.3472 | Function Loss:  -1.1121
# Total loss:  0.908 | PDE Loss:  -0.3473 | Function Loss:  -1.105
# Total loss:  0.9079 | PDE Loss:  -0.3473 | Function Loss:  -1.1063
# Total loss:  0.9079 | PDE Loss:  -0.3474 | Function Loss:  -1.1021
# Total loss:  0.9078 | PDE Loss:  -0.3474 | Function Loss:  -1.0956
# Total loss:  0.9077 | PDE Loss:  -0.3475 | Function Loss:  -1.0856
# Total loss:  0.9075 | PDE Loss:  -0.3476 | Function Loss:  -1.0753
# Total loss:  0.9073 | PDE Loss:  -0.3478 | Function Loss:  -1.0339
# Total loss:  0.907 | PDE Loss:  -0.3479 | Function Loss:  -1.0356
# Total loss:  0.9065 | PDE Loss:  -0.348 | Function Loss:  -1.0387
# Total loss:  0.9063 | PDE Loss:  -0.3487 | Function Loss:  -0.9476
# Total loss:  0.9056 | PDE Loss:  -0.3485 | Function Loss:  -1.0375
# Total loss:  0.9055 | PDE Loss:  -0.3495 | Function Loss:  -0.9492
# Total loss:  0.9046 | PDE Loss:  -0.3491 | Function Loss:  -1.0645
# Total loss:  0.9045 | PDE Loss:  -0.35 | Function Loss:  -0.9725
# Total loss:  0.9034 | PDE Loss:  -0.3496 | Function Loss:  -1.103
# Total loss:  0.9061 | PDE Loss:  -0.35 | Function Loss:  -0.8634
# Total loss:  0.9025 | PDE Loss:  -0.3498 | Function Loss:  -1.176
# Total loss:  0.9019 | PDE Loss:  -0.3501 | Function Loss:  -1.2179
# Total loss:  0.9013 | PDE Loss:  -0.3505 | Function Loss:  -1.2165
# Total loss:  0.9009 | PDE Loss:  -0.3505 | Function Loss:  -1.2578
# Total loss:  0.9004 | PDE Loss:  -0.3506 | Function Loss:  -1.2697
# Total loss:  0.9001 | PDE Loss:  -0.3507 | Function Loss:  -1.2703
# Total loss:  0.8998 | PDE Loss:  -0.3509 | Function Loss:  -1.2725
# Total loss:  0.8996 | PDE Loss:  -0.351 | Function Loss:  -1.2622
# Total loss:  0.8991 | PDE Loss:  -0.3513 | Function Loss:  -1.2503
# Total loss:  0.8987 | PDE Loss:  -0.3518 | Function Loss:  -1.1951
# Total loss:  0.898 | PDE Loss:  -0.3524 | Function Loss:  -1.1792
# Total loss:  0.8966 | PDE Loss:  -0.3534 | Function Loss:  -1.1775
# Total loss:  0.9291 | PDE Loss:  -0.3562 | Function Loss:  -0.1157
# Total loss:  0.8958 | PDE Loss:  -0.3543 | Function Loss:  -1.1125
# Total loss:  0.8968 | PDE Loss:  -0.3551 | Function Loss:  -0.9421
# Total loss:  0.8956 | PDE Loss:  -0.3546 | Function Loss:  -1.0946
# Total loss:  0.8953 | PDE Loss:  -0.3552 | Function Loss:  -1.0142
# Total loss:  0.8948 | PDE Loss:  -0.355 | Function Loss:  -1.0971
# Total loss:  0.8944 | PDE Loss:  -0.355 | Function Loss:  -1.1241
# Total loss:  0.8943 | PDE Loss:  -0.3549 | Function Loss:  -1.1391
# Total loss:  0.8939 | PDE Loss:  -0.3551 | Function Loss:  -1.159
# Total loss:  0.8934 | PDE Loss:  -0.3552 | Function Loss:  -1.1906
# Total loss:  0.8931 | PDE Loss:  -0.3556 | Function Loss:  -1.1705
# Total loss:  0.8928 | PDE Loss:  -0.3556 | Function Loss:  -1.2018
# Total loss:  0.8928 | PDE Loss:  -0.3556 | Function Loss:  -1.2012
# Total loss:  0.8926 | PDE Loss:  -0.3557 | Function Loss:  -1.2059
# Total loss:  0.8926 | PDE Loss:  -0.3558 | Function Loss:  -1.2077
# Total loss:  0.8925 | PDE Loss:  -0.3558 | Function Loss:  -1.2155
# Total loss:  0.8924 | PDE Loss:  -0.3558 | Function Loss:  -1.2198
# Total loss:  0.8924 | PDE Loss:  -0.3558 | Function Loss:  -1.229
# Total loss:  0.8923 | PDE Loss:  -0.3558 | Function Loss:  -1.2318
# Total loss:  0.8923 | PDE Loss:  -0.3558 | Function Loss:  -1.234
# Total loss:  0.8923 | PDE Loss:  -0.3558 | Function Loss:  -1.229
# Total loss:  0.8922 | PDE Loss:  -0.3559 | Function Loss:  -1.2173
# Total loss:  0.8921 | PDE Loss:  -0.3561 | Function Loss:  -1.1982
# Total loss:  0.8921 | PDE Loss:  -0.3562 | Function Loss:  -1.1725
# Total loss:  0.892 | PDE Loss:  -0.3565 | Function Loss:  -1.1413
# Total loss:  0.8919 | PDE Loss:  -0.3567 | Function Loss:  -1.105
# Total loss:  0.8918 | PDE Loss:  -0.357 | Function Loss:  -1.0724
# Total loss:  0.8917 | PDE Loss:  -0.3572 | Function Loss:  -1.0318
# Total loss:  0.8916 | PDE Loss:  -0.3573 | Function Loss:  -1.0273
# Total loss:  0.8915 | PDE Loss:  -0.3573 | Function Loss:  -1.0155
# Total loss:  0.8914 | PDE Loss:  -0.3575 | Function Loss:  -0.9877
# Total loss:  0.8913 | PDE Loss:  -0.3575 | Function Loss:  -0.978
# Total loss:  0.8911 | PDE Loss:  -0.3574 | Function Loss:  -0.9747
# Total loss:  0.8907 | PDE Loss:  -0.3572 | Function Loss:  -0.9789
# Total loss:  0.8899 | PDE Loss:  -0.3569 | Function Loss:  -1.0171
# Total loss:  0.8899 | PDE Loss:  -0.3572 | Function Loss:  -0.9371
# Total loss:  0.8895 | PDE Loss:  -0.3571 | Function Loss:  -0.9932
# Total loss:  0.8891 | PDE Loss:  -0.3568 | Function Loss:  -0.955
# Total loss:  0.8887 | PDE Loss:  -0.3567 | Function Loss:  -0.9702
# Total loss:  0.8885 | PDE Loss:  -0.3588 | Function Loss:  -0.9094
# Total loss:  0.8873 | PDE Loss:  -0.359 | Function Loss:  -0.9936
# Total loss:  0.8867 | PDE Loss:  -0.3591 | Function Loss:  -1.0306
# Total loss:  0.8863 | PDE Loss:  -0.3594 | Function Loss:  -1.0297
# Total loss:  0.8859 | PDE Loss:  -0.3598 | Function Loss:  -1.03
# Total loss:  0.8857 | PDE Loss:  -0.3603 | Function Loss:  -0.9974
# Total loss:  0.8855 | PDE Loss:  -0.3604 | Function Loss:  -1.0059
# Total loss:  0.8855 | PDE Loss:  -0.3605 | Function Loss:  -1.0025
# Total loss:  0.8854 | PDE Loss:  -0.3605 | Function Loss:  -0.9981
# Total loss:  0.8854 | PDE Loss:  -0.3605 | Function Loss:  -0.9947
# Total loss:  0.8853 | PDE Loss:  -0.3606 | Function Loss:  -0.9928
# Total loss:  0.8853 | PDE Loss:  -0.3606 | Function Loss:  -0.9934
# Total loss:  0.8852 | PDE Loss:  -0.3606 | Function Loss:  -0.9961
# Total loss:  0.8851 | PDE Loss:  -0.3605 | Function Loss:  -1.0038
# Total loss:  0.885 | PDE Loss:  -0.3605 | Function Loss:  -1.0135
# Total loss:  0.8849 | PDE Loss:  -0.3604 | Function Loss:  -1.0302
# Total loss:  0.8847 | PDE Loss:  -0.3604 | Function Loss:  -1.0475
# Total loss:  0.8845 | PDE Loss:  -0.3603 | Function Loss:  -1.0711
# Total loss:  0.8844 | PDE Loss:  -0.3603 | Function Loss:  -1.0896
# Total loss:  0.8843 | PDE Loss:  -0.3602 | Function Loss:  -1.1073
# Total loss:  0.8842 | PDE Loss:  -0.3602 | Function Loss:  -1.1235
# Total loss:  0.8841 | PDE Loss:  -0.3601 | Function Loss:  -1.1432
# Total loss:  0.8839 | PDE Loss:  -0.3601 | Function Loss:  -1.1621
# Total loss:  0.8836 | PDE Loss:  -0.3601 | Function Loss:  -1.183
# Total loss:  0.8835 | PDE Loss:  -0.3602 | Function Loss:  -1.1828
# Total loss:  0.8832 | PDE Loss:  -0.3604 | Function Loss:  -1.1752
# Total loss:  0.8829 | PDE Loss:  -0.3607 | Function Loss:  -1.1665
# Total loss:  0.8826 | PDE Loss:  -0.361 | Function Loss:  -1.1281
# Total loss:  0.8824 | PDE Loss:  -0.3613 | Function Loss:  -1.0991
# Total loss:  0.8823 | PDE Loss:  -0.3616 | Function Loss:  -1.0609
# Total loss:  0.8822 | PDE Loss:  -0.3619 | Function Loss:  -1.0378
# Total loss:  0.8821 | PDE Loss:  -0.362 | Function Loss:  -1.0288
# Total loss:  0.8821 | PDE Loss:  -0.3619 | Function Loss:  -1.042
# Total loss:  0.882 | PDE Loss:  -0.3619 | Function Loss:  -1.0478
# Total loss:  0.8819 | PDE Loss:  -0.3619 | Function Loss:  -1.0594
# Total loss:  0.8818 | PDE Loss:  -0.362 | Function Loss:  -1.0695
# Total loss:  0.8817 | PDE Loss:  -0.362 | Function Loss:  -1.0779
# Total loss:  0.8816 | PDE Loss:  -0.362 | Function Loss:  -1.0827
# Total loss:  0.8816 | PDE Loss:  -0.3622 | Function Loss:  -1.0766
# Total loss:  0.8815 | PDE Loss:  -0.3623 | Function Loss:  -1.0703
# Total loss:  0.8815 | PDE Loss:  -0.3624 | Function Loss:  -1.0507
# Total loss:  0.8814 | PDE Loss:  -0.3625 | Function Loss:  -1.0466
# Total loss:  0.8814 | PDE Loss:  -0.3625 | Function Loss:  -1.0432
# Total loss:  0.8814 | PDE Loss:  -0.3625 | Function Loss:  -1.045
# Total loss:  0.8814 | PDE Loss:  -0.3625 | Function Loss:  -1.0482
# Total loss:  0.8813 | PDE Loss:  -0.3625 | Function Loss:  -1.0524
# Total loss:  0.8813 | PDE Loss:  -0.3624 | Function Loss:  -1.0573
# Total loss:  0.8813 | PDE Loss:  -0.3624 | Function Loss:  -1.0627
# Total loss:  0.8813 | PDE Loss:  -0.3624 | Function Loss:  -1.068
# Total loss:  0.8813 | PDE Loss:  -0.3623 | Function Loss:  -1.0728
# Total loss:  0.8813 | PDE Loss:  -0.3623 | Function Loss:  -1.077
# Total loss:  0.8813 | PDE Loss:  -0.3623 | Function Loss:  -1.0806
# Total loss:  0.8813 | PDE Loss:  -0.3623 | Function Loss:  -1.0848
# Total loss:  0.8812 | PDE Loss:  -0.3623 | Function Loss:  -1.0895
# Total loss:  0.8812 | PDE Loss:  -0.3623 | Function Loss:  -1.0967
# Total loss:  0.8811 | PDE Loss:  -0.3623 | Function Loss:  -1.1052
# Total loss:  0.881 | PDE Loss:  -0.3623 | Function Loss:  -1.1157
# Total loss:  0.8809 | PDE Loss:  -0.3624 | Function Loss:  -1.133
# Total loss:  0.8805 | PDE Loss:  -0.3626 | Function Loss:  -1.1514
# Total loss:  0.8802 | PDE Loss:  -0.3628 | Function Loss:  -1.1587
# Total loss:  0.88 | PDE Loss:  -0.3629 | Function Loss:  -1.1691
# Total loss:  0.8795 | PDE Loss:  -0.3632 | Function Loss:  -1.1643
# Total loss:  0.8788 | PDE Loss:  -0.3633 | Function Loss:  -1.2311
# Total loss:  0.8785 | PDE Loss:  -0.3633 | Function Loss:  -1.2549
# Total loss:  0.8782 | PDE Loss:  -0.3635 | Function Loss:  -1.2518
# Total loss:  0.8781 | PDE Loss:  -0.3635 | Function Loss:  -1.2577
# Total loss:  0.8781 | PDE Loss:  -0.3635 | Function Loss:  -1.2722
# Total loss:  0.878 | PDE Loss:  -0.3635 | Function Loss:  -1.2793
# Total loss:  0.8779 | PDE Loss:  -0.3635 | Function Loss:  -1.3011
# Total loss:  0.8778 | PDE Loss:  -0.3635 | Function Loss:  -1.329
# Total loss:  0.8776 | PDE Loss:  -0.3635 | Function Loss:  -1.3674
# Total loss:  0.8774 | PDE Loss:  -0.3635 | Function Loss:  -1.41
# Total loss:  0.8772 | PDE Loss:  -0.3635 | Function Loss:  -1.4344
# Total loss:  0.8771 | PDE Loss:  -0.3635 | Function Loss:  -1.4694
# Total loss:  0.877 | PDE Loss:  -0.3636 | Function Loss:  -1.4627
# Total loss:  0.8769 | PDE Loss:  -0.3636 | Function Loss:  -1.4747
# Total loss:  0.8767 | PDE Loss:  -0.3638 | Function Loss:  -1.46
# Total loss:  0.8765 | PDE Loss:  -0.3639 | Function Loss:  -1.4605
# Total loss:  0.8763 | PDE Loss:  -0.3641 | Function Loss:  -1.459
# Total loss:  0.876 | PDE Loss:  -0.3645 | Function Loss:  -1.43
# Total loss:  0.8753 | PDE Loss:  -0.3653 | Function Loss:  -1.3657
# Total loss:  0.8748 | PDE Loss:  -0.366 | Function Loss:  -1.2968
# Total loss:  0.875 | PDE Loss:  -0.3675 | Function Loss:  -1.0381
# Total loss:  0.8742 | PDE Loss:  -0.3669 | Function Loss:  -1.2163
# Total loss:  0.874 | PDE Loss:  -0.3678 | Function Loss:  -1.1138
# Total loss:  0.8745 | PDE Loss:  -0.3683 | Function Loss:  -1.0201
# Total loss:  0.8738 | PDE Loss:  -0.368 | Function Loss:  -1.1139
# Total loss:  0.8734 | PDE Loss:  -0.3679 | Function Loss:  -1.1725
# Total loss:  0.8734 | PDE Loss:  -0.368 | Function Loss:  -1.1673
# Total loss:  0.8733 | PDE Loss:  -0.3681 | Function Loss:  -1.1551
# Total loss:  0.8733 | PDE Loss:  -0.3682 | Function Loss:  -1.1485
# Total loss:  0.8733 | PDE Loss:  -0.3683 | Function Loss:  -1.143
# Total loss:  0.8732 | PDE Loss:  -0.3684 | Function Loss:  -1.1339
# Total loss:  0.8732 | PDE Loss:  -0.3685 | Function Loss:  -1.1258
# Total loss:  0.8732 | PDE Loss:  -0.3686 | Function Loss:  -1.1175
# Total loss:  0.8731 | PDE Loss:  -0.3687 | Function Loss:  -1.1108
# Total loss:  0.873 | PDE Loss:  -0.3689 | Function Loss:  -1.095
# Total loss:  0.8728 | PDE Loss:  -0.3691 | Function Loss:  -1.0869
# Total loss:  0.8727 | PDE Loss:  -0.3697 | Function Loss:  -1.0411
# Total loss:  0.8724 | PDE Loss:  -0.3699 | Function Loss:  -1.0384
# Total loss:  0.8719 | PDE Loss:  -0.3704 | Function Loss:  -1.0326
# Total loss:  0.8711 | PDE Loss:  -0.371 | Function Loss:  -1.047
# Total loss:  0.8709 | PDE Loss:  -0.3716 | Function Loss:  -0.9931
# Total loss:  0.8708 | PDE Loss:  -0.3714 | Function Loss:  -1.028
# Total loss:  0.87 | PDE Loss:  -0.372 | Function Loss:  -1.0213
# Total loss:  0.8697 | PDE Loss:  -0.3719 | Function Loss:  -1.0442
# Total loss:  0.8696 | PDE Loss:  -0.372 | Function Loss:  -1.0534
# Total loss:  0.8691 | PDE Loss:  -0.3721 | Function Loss:  -1.0829
# Total loss:  0.8688 | PDE Loss:  -0.3718 | Function Loss:  -1.1331
# Total loss:  0.8686 | PDE Loss:  -0.3716 | Function Loss:  -1.1866
# Total loss:  0.8684 | PDE Loss:  -0.3716 | Function Loss:  -1.2007
# Total loss:  0.8683 | PDE Loss:  -0.3715 | Function Loss:  -1.2284
# Total loss:  0.8681 | PDE Loss:  -0.3716 | Function Loss:  -1.2292
# Total loss:  0.868 | PDE Loss:  -0.3717 | Function Loss:  -1.2301
# Total loss:  0.8676 | PDE Loss:  -0.372 | Function Loss:  -1.233
# Total loss:  0.8671 | PDE Loss:  -0.3723 | Function Loss:  -1.23
# Total loss:  0.8667 | PDE Loss:  -0.3727 | Function Loss:  -1.2082
# Total loss:  0.8757 | PDE Loss:  -0.3743 | Function Loss:  -0.6119
# Total loss:  0.8664 | PDE Loss:  -0.3732 | Function Loss:  -1.1777
# Total loss:  0.866 | PDE Loss:  -0.3736 | Function Loss:  -1.1938
# Total loss:  0.8656 | PDE Loss:  -0.3743 | Function Loss:  -1.1644
# Total loss:  0.8654 | PDE Loss:  -0.3748 | Function Loss:  -1.1437
# Total loss:  0.8653 | PDE Loss:  -0.3749 | Function Loss:  -1.1376
# Total loss:  0.8652 | PDE Loss:  -0.3751 | Function Loss:  -1.1273
# Total loss:  0.8651 | PDE Loss:  -0.3751 | Function Loss:  -1.1313
# Total loss:  0.865 | PDE Loss:  -0.3751 | Function Loss:  -1.1398
# Total loss:  0.8648 | PDE Loss:  -0.3751 | Function Loss:  -1.1558
# Total loss:  0.8647 | PDE Loss:  -0.3748 | Function Loss:  -1.1993
# Total loss:  0.8645 | PDE Loss:  -0.3748 | Function Loss:  -1.2172
# Total loss:  0.8643 | PDE Loss:  -0.3748 | Function Loss:  -1.2451
# Total loss:  0.8642 | PDE Loss:  -0.3749 | Function Loss:  -1.2537
# Total loss:  0.864 | PDE Loss:  -0.375 | Function Loss:  -1.2712
# Total loss:  0.8639 | PDE Loss:  -0.3751 | Function Loss:  -1.2741
# Total loss:  0.8638 | PDE Loss:  -0.3752 | Function Loss:  -1.2679
# Total loss:  0.8636 | PDE Loss:  -0.3754 | Function Loss:  -1.2588
# Total loss:  0.8634 | PDE Loss:  -0.3758 | Function Loss:  -1.2312
# Total loss:  0.863 | PDE Loss:  -0.3763 | Function Loss:  -1.2053
# Total loss:  0.8671 | PDE Loss:  -0.378 | Function Loss:  -0.7959
# Total loss:  0.8629 | PDE Loss:  -0.3769 | Function Loss:  -1.1606
# Total loss:  0.8625 | PDE Loss:  -0.3775 | Function Loss:  -1.1367
# Total loss:  0.862 | PDE Loss:  -0.378 | Function Loss:  -1.1375
# Total loss:  0.8619 | PDE Loss:  -0.3787 | Function Loss:  -1.0874
# Total loss:  0.8616 | PDE Loss:  -0.3788 | Function Loss:  -1.1036
# Total loss:  0.8614 | PDE Loss:  -0.379 | Function Loss:  -1.1086
# Total loss:  0.861 | PDE Loss:  -0.3793 | Function Loss:  -1.1036
# Total loss:  0.8607 | PDE Loss:  -0.3795 | Function Loss:  -1.1113
# Total loss:  0.8611 | PDE Loss:  -0.3802 | Function Loss:  -1.018
# Total loss:  0.8606 | PDE Loss:  -0.3798 | Function Loss:  -1.094
# Total loss:  0.8604 | PDE Loss:  -0.38 | Function Loss:  -1.0949
# Total loss:  0.8603 | PDE Loss:  -0.3803 | Function Loss:  -1.0834
# Total loss:  0.8602 | PDE Loss:  -0.3805 | Function Loss:  -1.0793
# Total loss:  0.8601 | PDE Loss:  -0.3807 | Function Loss:  -1.0677
# Total loss:  0.8598 | PDE Loss:  -0.3813 | Function Loss:  -1.0452
# Total loss:  0.8597 | PDE Loss:  -0.3821 | Function Loss:  -1.0094
# Total loss:  0.8593 | PDE Loss:  -0.383 | Function Loss:  -0.9708
# Total loss:  0.8592 | PDE Loss:  -0.3832 | Function Loss:  -0.9644
# Total loss:  0.8591 | PDE Loss:  -0.3835 | Function Loss:  -0.954
# Total loss:  0.859 | PDE Loss:  -0.3837 | Function Loss:  -0.944
# Total loss:  0.859 | PDE Loss:  -0.384 | Function Loss:  -0.9267
# Total loss:  0.859 | PDE Loss:  -0.3841 | Function Loss:  -0.9253
# Total loss:  0.859 | PDE Loss:  -0.3841 | Function Loss:  -0.9244
# Total loss:  0.8589 | PDE Loss:  -0.3841 | Function Loss:  -0.9225
# Total loss:  0.8589 | PDE Loss:  -0.3842 | Function Loss:  -0.9214
# Total loss:  0.8589 | PDE Loss:  -0.3843 | Function Loss:  -0.9192
# Total loss:  0.8589 | PDE Loss:  -0.3843 | Function Loss:  -0.917
# Total loss:  0.8589 | PDE Loss:  -0.3844 | Function Loss:  -0.9133
# Total loss:  0.8588 | PDE Loss:  -0.3845 | Function Loss:  -0.9096
# Total loss:  0.8588 | PDE Loss:  -0.3846 | Function Loss:  -0.9041
# Total loss:  0.8588 | PDE Loss:  -0.3847 | Function Loss:  -0.8995
# Total loss:  0.8588 | PDE Loss:  -0.3849 | Function Loss:  -0.8914
# Total loss:  0.8588 | PDE Loss:  -0.385 | Function Loss:  -0.8858
# Total loss:  0.8587 | PDE Loss:  -0.3852 | Function Loss:  -0.8779
# Total loss:  0.8587 | PDE Loss:  -0.3855 | Function Loss:  -0.8705
# Total loss:  0.8586 | PDE Loss:  -0.3859 | Function Loss:  -0.8578
# Total loss:  0.8584 | PDE Loss:  -0.3862 | Function Loss:  -0.8519
# Total loss:  0.8583 | PDE Loss:  -0.3865 | Function Loss:  -0.8476
# Total loss:  0.8582 | PDE Loss:  -0.3866 | Function Loss:  -0.8548
# Total loss:  0.858 | PDE Loss:  -0.3865 | Function Loss:  -0.8692
# Total loss:  0.8579 | PDE Loss:  -0.3866 | Function Loss:  -0.8763
# Total loss:  0.8576 | PDE Loss:  -0.3865 | Function Loss:  -0.8938
# Total loss:  0.8574 | PDE Loss:  -0.3865 | Function Loss:  -0.9057
# Total loss:  0.8571 | PDE Loss:  -0.3866 | Function Loss:  -0.9207
# Total loss:  0.857 | PDE Loss:  -0.3869 | Function Loss:  -0.9117
# Total loss:  0.8569 | PDE Loss:  -0.3868 | Function Loss:  -0.9219
# Total loss:  0.8566 | PDE Loss:  -0.387 | Function Loss:  -0.9266
# Total loss:  0.8564 | PDE Loss:  -0.387 | Function Loss:  -0.9354
# Total loss:  0.8562 | PDE Loss:  -0.3872 | Function Loss:  -0.9365
# Total loss:  0.856 | PDE Loss:  -0.3874 | Function Loss:  -0.9404
# Total loss:  0.8559 | PDE Loss:  -0.3882 | Function Loss:  -0.9138
# Total loss:  0.8556 | PDE Loss:  -0.3883 | Function Loss:  -0.9247
# Total loss:  0.8553 | PDE Loss:  -0.3886 | Function Loss:  -0.9276
# Total loss:  0.8553 | PDE Loss:  -0.3893 | Function Loss:  -0.8998
# Total loss:  0.8552 | PDE Loss:  -0.389 | Function Loss:  -0.9186
# Total loss:  0.855 | PDE Loss:  -0.3894 | Function Loss:  -0.9183
# Total loss:  0.8548 | PDE Loss:  -0.3897 | Function Loss:  -0.9181
# Total loss:  0.8546 | PDE Loss:  -0.39 | Function Loss:  -0.9117
# Total loss:  0.8545 | PDE Loss:  -0.3902 | Function Loss:  -0.9119
# Total loss:  0.8544 | PDE Loss:  -0.3905 | Function Loss:  -0.9032
# Total loss:  0.8544 | PDE Loss:  -0.3907 | Function Loss:  -0.9002
# Total loss:  0.8543 | PDE Loss:  -0.3909 | Function Loss:  -0.897
# Total loss:  0.854 | PDE Loss:  -0.3914 | Function Loss:  -0.8934
# Total loss:  0.8538 | PDE Loss:  -0.3919 | Function Loss:  -0.8903
# Total loss:  0.8536 | PDE Loss:  -0.3924 | Function Loss:  -0.8874
# Total loss:  0.8536 | PDE Loss:  -0.3934 | Function Loss:  -0.8498
# Total loss:  0.8534 | PDE Loss:  -0.393 | Function Loss:  -0.8758
# Total loss:  0.8532 | PDE Loss:  -0.3932 | Function Loss:  -0.8768
# Total loss:  0.8529 | PDE Loss:  -0.3936 | Function Loss:  -0.8765
# Total loss:  0.8527 | PDE Loss:  -0.3942 | Function Loss:  -0.866
# Total loss:  0.8525 | PDE Loss:  -0.3942 | Function Loss:  -0.8742
# Total loss:  0.8524 | PDE Loss:  -0.3943 | Function Loss:  -0.8729
# Total loss:  0.8524 | PDE Loss:  -0.3943 | Function Loss:  -0.8746
# Total loss:  0.8524 | PDE Loss:  -0.3943 | Function Loss:  -0.8781
# Total loss:  0.8523 | PDE Loss:  -0.3943 | Function Loss:  -0.8815
# Total loss:  0.8522 | PDE Loss:  -0.3943 | Function Loss:  -0.8851
# Total loss:  0.8522 | PDE Loss:  -0.3944 | Function Loss:  -0.8879
# Total loss:  0.8521 | PDE Loss:  -0.3944 | Function Loss:  -0.8907
# Total loss:  0.8521 | PDE Loss:  -0.3945 | Function Loss:  -0.8931
# Total loss:  0.852 | PDE Loss:  -0.3946 | Function Loss:  -0.8937
# Total loss:  0.852 | PDE Loss:  -0.3946 | Function Loss:  -0.8953
# Total loss:  0.852 | PDE Loss:  -0.3947 | Function Loss:  -0.8954
# Total loss:  0.852 | PDE Loss:  -0.3947 | Function Loss:  -0.8963
# Total loss:  0.8519 | PDE Loss:  -0.3947 | Function Loss:  -0.8975
# Total loss:  0.8519 | PDE Loss:  -0.3947 | Function Loss:  -0.8986
# Total loss:  0.8519 | PDE Loss:  -0.3947 | Function Loss:  -0.9015
# Total loss:  0.8518 | PDE Loss:  -0.3946 | Function Loss:  -0.9048
# Total loss:  0.8518 | PDE Loss:  -0.3946 | Function Loss:  -0.9107
# Total loss:  0.8517 | PDE Loss:  -0.3946 | Function Loss:  -0.9174
# Total loss:  0.8516 | PDE Loss:  -0.3946 | Function Loss:  -0.9268
# Total loss:  0.8515 | PDE Loss:  -0.3946 | Function Loss:  -0.9362
# Total loss:  0.8514 | PDE Loss:  -0.3946 | Function Loss:  -0.9468
# Total loss:  0.8513 | PDE Loss:  -0.3946 | Function Loss:  -0.9579
# Total loss:  0.8512 | PDE Loss:  -0.3946 | Function Loss:  -0.9694
# Total loss:  0.8511 | PDE Loss:  -0.3945 | Function Loss:  -0.9844
# Total loss:  0.851 | PDE Loss:  -0.3945 | Function Loss:  -0.9962
# Total loss:  0.8509 | PDE Loss:  -0.3943 | Function Loss:  -1.0102
# Total loss:  0.8508 | PDE Loss:  -0.3942 | Function Loss:  -1.0276
# Total loss:  0.8507 | PDE Loss:  -0.3939 | Function Loss:  -1.0519
# Total loss:  0.8506 | PDE Loss:  -0.3936 | Function Loss:  -1.0775
# Total loss:  0.8505 | PDE Loss:  -0.3934 | Function Loss:  -1.1011
# Total loss:  0.8504 | PDE Loss:  -0.3932 | Function Loss:  -1.1226
# Total loss:  0.8503 | PDE Loss:  -0.3931 | Function Loss:  -1.1334
# Total loss:  0.8503 | PDE Loss:  -0.393 | Function Loss:  -1.1435
# Total loss:  0.8502 | PDE Loss:  -0.3929 | Function Loss:  -1.152
# Total loss:  0.8501 | PDE Loss:  -0.3928 | Function Loss:  -1.1667
# Total loss:  0.85 | PDE Loss:  -0.3928 | Function Loss:  -1.1721
# Total loss:  0.85 | PDE Loss:  -0.3928 | Function Loss:  -1.1813
# Total loss:  0.8499 | PDE Loss:  -0.3928 | Function Loss:  -1.1823
# Total loss:  0.8498 | PDE Loss:  -0.3928 | Function Loss:  -1.1865
# Total loss:  0.8498 | PDE Loss:  -0.3928 | Function Loss:  -1.1853
# Total loss:  0.8498 | PDE Loss:  -0.3928 | Function Loss:  -1.1869
# Total loss:  0.8498 | PDE Loss:  -0.3928 | Function Loss:  -1.1877
# Total loss:  0.8498 | PDE Loss:  -0.3928 | Function Loss:  -1.1893
# Total loss:  0.8498 | PDE Loss:  -0.3928 | Function Loss:  -1.1925
# Total loss:  0.8498 | PDE Loss:  -0.3928 | Function Loss:  -1.197
# Total loss:  0.8497 | PDE Loss:  -0.3927 | Function Loss:  -1.2042
# Total loss:  0.8497 | PDE Loss:  -0.3927 | Function Loss:  -1.2112
# Total loss:  0.8497 | PDE Loss:  -0.3926 | Function Loss:  -1.2228
# Total loss:  0.8496 | PDE Loss:  -0.3926 | Function Loss:  -1.2288
# Total loss:  0.8496 | PDE Loss:  -0.3926 | Function Loss:  -1.2344
# Total loss:  0.8496 | PDE Loss:  -0.3926 | Function Loss:  -1.2384
# Total loss:  0.8495 | PDE Loss:  -0.3926 | Function Loss:  -1.2423
# Total loss:  0.8495 | PDE Loss:  -0.3927 | Function Loss:  -1.2426
# Total loss:  0.8494 | PDE Loss:  -0.3928 | Function Loss:  -1.2404
# Total loss:  0.8493 | PDE Loss:  -0.393 | Function Loss:  -1.2354
# Total loss:  0.8492 | PDE Loss:  -0.3933 | Function Loss:  -1.2224
# Total loss:  0.8491 | PDE Loss:  -0.3936 | Function Loss:  -1.2195
# Total loss:  0.8489 | PDE Loss:  -0.394 | Function Loss:  -1.2088
# Total loss:  0.8487 | PDE Loss:  -0.3943 | Function Loss:  -1.2085
# Total loss:  0.8486 | PDE Loss:  -0.3946 | Function Loss:  -1.206
# Total loss:  0.8485 | PDE Loss:  -0.3951 | Function Loss:  -1.1807
# Total loss:  0.8483 | PDE Loss:  -0.3953 | Function Loss:  -1.1872
# Total loss:  0.8483 | PDE Loss:  -0.3954 | Function Loss:  -1.1821
# Total loss:  0.8482 | PDE Loss:  -0.3955 | Function Loss:  -1.1806
# Total loss:  0.848 | PDE Loss:  -0.3958 | Function Loss:  -1.1755
# Total loss:  0.8479 | PDE Loss:  -0.3962 | Function Loss:  -1.1526
# Total loss:  0.8479 | PDE Loss:  -0.3961 | Function Loss:  -1.1606
# Total loss:  0.8478 | PDE Loss:  -0.3962 | Function Loss:  -1.1597
# Total loss:  0.8478 | PDE Loss:  -0.3963 | Function Loss:  -1.1559
# Total loss:  0.8477 | PDE Loss:  -0.3965 | Function Loss:  -1.1473
# Total loss:  0.8477 | PDE Loss:  -0.3966 | Function Loss:  -1.1415
# Total loss:  0.8477 | PDE Loss:  -0.3968 | Function Loss:  -1.1335
# Total loss:  0.8476 | PDE Loss:  -0.397 | Function Loss:  -1.1302
# Total loss:  0.8476 | PDE Loss:  -0.3971 | Function Loss:  -1.1262
# Total loss:  0.8476 | PDE Loss:  -0.3972 | Function Loss:  -1.1209
# Total loss:  0.8476 | PDE Loss:  -0.3974 | Function Loss:  -1.1143
# Total loss:  0.8475 | PDE Loss:  -0.3975 | Function Loss:  -1.1075
# Total loss:  0.8475 | PDE Loss:  -0.3979 | Function Loss:  -1.0831
# Total loss:  0.8475 | PDE Loss:  -0.3977 | Function Loss:  -1.0968
# Total loss:  0.8475 | PDE Loss:  -0.3978 | Function Loss:  -1.0917
# Total loss:  0.8475 | PDE Loss:  -0.3981 | Function Loss:  -1.0799
# Total loss:  0.8475 | PDE Loss:  -0.3981 | Function Loss:  -1.0794
# Total loss:  0.8475 | PDE Loss:  -0.3982 | Function Loss:  -1.0748
# Total loss:  0.8475 | PDE Loss:  -0.3982 | Function Loss:  -1.0716
# Total loss:  0.8475 | PDE Loss:  -0.3983 | Function Loss:  -1.0708
# Total loss:  0.8474 | PDE Loss:  -0.3983 | Function Loss:  -1.0698
# Total loss:  0.8474 | PDE Loss:  -0.3983 | Function Loss:  -1.0682
# Total loss:  0.8474 | PDE Loss:  -0.3983 | Function Loss:  -1.0678
# Total loss:  0.8474 | PDE Loss:  -0.3983 | Function Loss:  -1.0686
# Total loss:  0.8474 | PDE Loss:  -0.3983 | Function Loss:  -1.0714
# Total loss:  0.8473 | PDE Loss:  -0.3982 | Function Loss:  -1.0767
# Total loss:  0.8472 | PDE Loss:  -0.3982 | Function Loss:  -1.0806
# Total loss:  0.8472 | PDE Loss:  -0.3982 | Function Loss:  -1.0838
# Total loss:  0.8471 | PDE Loss:  -0.3982 | Function Loss:  -1.0819
# Total loss:  0.8471 | PDE Loss:  -0.3982 | Function Loss:  -1.0819
# Total loss:  0.8471 | PDE Loss:  -0.3983 | Function Loss:  -1.0799
# Total loss:  0.8471 | PDE Loss:  -0.3983 | Function Loss:  -1.0793
# Total loss:  0.8471 | PDE Loss:  -0.3983 | Function Loss:  -1.079
# Total loss:  0.847 | PDE Loss:  -0.3983 | Function Loss:  -1.0797
# Total loss:  0.847 | PDE Loss:  -0.3983 | Function Loss:  -1.0799
# Total loss:  0.847 | PDE Loss:  -0.3982 | Function Loss:  -1.083
# Total loss:  0.847 | PDE Loss:  -0.3982 | Function Loss:  -1.084
# Total loss:  0.847 | PDE Loss:  -0.3982 | Function Loss:  -1.0858
# Total loss:  0.847 | PDE Loss:  -0.3981 | Function Loss:  -1.0861
# Total loss:  0.8469 | PDE Loss:  -0.3981 | Function Loss:  -1.0863
# Total loss:  0.8469 | PDE Loss:  -0.3982 | Function Loss:  -1.0822
# Total loss:  0.8469 | PDE Loss:  -0.3982 | Function Loss:  -1.0815
# Total loss:  0.8469 | PDE Loss:  -0.3982 | Function Loss:  -1.0797
# Total loss:  0.8469 | PDE Loss:  -0.3982 | Function Loss:  -1.0778
# Total loss:  0.8469 | PDE Loss:  -0.3983 | Function Loss:  -1.0762
# Total loss:  0.8468 | PDE Loss:  -0.3983 | Function Loss:  -1.0768
# Total loss:  0.8468 | PDE Loss:  -0.3983 | Function Loss:  -1.0767
# Total loss:  0.8468 | PDE Loss:  -0.3983 | Function Loss:  -1.0788
# Total loss:  0.8468 | PDE Loss:  -0.3983 | Function Loss:  -1.0814
# Total loss:  0.8468 | PDE Loss:  -0.3982 | Function Loss:  -1.0867
# Total loss:  0.8468 | PDE Loss:  -0.3982 | Function Loss:  -1.0933
# Total loss:  0.8468 | PDE Loss:  -0.3982 | Function Loss:  -1.0988
# Total loss:  0.8467 | PDE Loss:  -0.3982 | Function Loss:  -1.1035
# Total loss:  0.8467 | PDE Loss:  -0.3981 | Function Loss:  -1.1063
# Total loss:  0.8467 | PDE Loss:  -0.3981 | Function Loss:  -1.1073
# Total loss:  0.8466 | PDE Loss:  -0.3981 | Function Loss:  -1.1082
# Total loss:  0.8466 | PDE Loss:  -0.3981 | Function Loss:  -1.1089
# Total loss:  0.8465 | PDE Loss:  -0.3982 | Function Loss:  -1.1093
# Total loss:  0.8464 | PDE Loss:  -0.3982 | Function Loss:  -1.1089
# Total loss:  0.8468 | PDE Loss:  -0.3983 | Function Loss:  -1.0387
# Total loss:  0.8462 | PDE Loss:  -0.3983 | Function Loss:  -1.1028
# Total loss:  0.846 | PDE Loss:  -0.3984 | Function Loss:  -1.1047
# Total loss:  0.8458 | PDE Loss:  -0.3986 | Function Loss:  -1.1073
# Total loss:  0.8456 | PDE Loss:  -0.3988 | Function Loss:  -1.1001
# Total loss:  0.8458 | PDE Loss:  -0.3992 | Function Loss:  -1.0556
# Total loss:  0.8453 | PDE Loss:  -0.399 | Function Loss:  -1.1127
# Total loss:  0.8461 | PDE Loss:  -0.399 | Function Loss:  -1.0427
# Total loss:  0.8451 | PDE Loss:  -0.3991 | Function Loss:  -1.1241
# Total loss:  0.845 | PDE Loss:  -0.3991 | Function Loss:  -1.1305
# Total loss:  0.8449 | PDE Loss:  -0.3991 | Function Loss:  -1.1491
# Total loss:  0.8447 | PDE Loss:  -0.3992 | Function Loss:  -1.152
# Total loss:  0.8446 | PDE Loss:  -0.3992 | Function Loss:  -1.1611
# Total loss:  0.8445 | PDE Loss:  -0.3993 | Function Loss:  -1.1646
# Total loss:  0.8443 | PDE Loss:  -0.3995 | Function Loss:  -1.164
# Total loss:  0.8441 | PDE Loss:  -0.3996 | Function Loss:  -1.1623
# Total loss:  0.844 | PDE Loss:  -0.3998 | Function Loss:  -1.1536
# Total loss:  0.8439 | PDE Loss:  -0.3999 | Function Loss:  -1.1506
# Total loss:  0.8439 | PDE Loss:  -0.4 | Function Loss:  -1.1464
# Total loss:  0.8437 | PDE Loss:  -0.4002 | Function Loss:  -1.1401
# Total loss:  0.8436 | PDE Loss:  -0.4004 | Function Loss:  -1.1251
# Total loss:  0.8436 | PDE Loss:  -0.4004 | Function Loss:  -1.1297
# Total loss:  0.8435 | PDE Loss:  -0.4005 | Function Loss:  -1.1344
# Total loss:  0.8434 | PDE Loss:  -0.4006 | Function Loss:  -1.1322
# Total loss:  0.8433 | PDE Loss:  -0.4006 | Function Loss:  -1.1337
# Total loss:  0.8433 | PDE Loss:  -0.4007 | Function Loss:  -1.1378
# Total loss:  0.8432 | PDE Loss:  -0.4008 | Function Loss:  -1.134
# Total loss:  0.8432 | PDE Loss:  -0.4009 | Function Loss:  -1.1333
# Total loss:  0.8431 | PDE Loss:  -0.4011 | Function Loss:  -1.1272
# Total loss:  0.843 | PDE Loss:  -0.4013 | Function Loss:  -1.1226
# Total loss:  0.8429 | PDE Loss:  -0.4016 | Function Loss:  -1.1113
# Total loss:  0.8428 | PDE Loss:  -0.4018 | Function Loss:  -1.105
# Total loss:  0.8427 | PDE Loss:  -0.4021 | Function Loss:  -1.0933
# Total loss:  0.8426 | PDE Loss:  -0.4023 | Function Loss:  -1.0871
# Total loss:  0.8425 | PDE Loss:  -0.4029 | Function Loss:  -1.0543
# Total loss:  0.8424 | PDE Loss:  -0.403 | Function Loss:  -1.0554
# Total loss:  0.8423 | PDE Loss:  -0.4034 | Function Loss:  -1.0334
# Total loss:  0.8422 | PDE Loss:  -0.4035 | Function Loss:  -1.0335
# Total loss:  0.8422 | PDE Loss:  -0.4035 | Function Loss:  -1.0341
# Total loss:  0.8421 | PDE Loss:  -0.4035 | Function Loss:  -1.0387
# Total loss:  0.842 | PDE Loss:  -0.4036 | Function Loss:  -1.0378
# Total loss:  0.8419 | PDE Loss:  -0.4037 | Function Loss:  -1.0367
# Total loss:  0.8418 | PDE Loss:  -0.4038 | Function Loss:  -1.0387
# Total loss:  0.8417 | PDE Loss:  -0.4039 | Function Loss:  -1.0443
# Total loss:  0.8417 | PDE Loss:  -0.4039 | Function Loss:  -1.0435
# Total loss:  0.8416 | PDE Loss:  -0.4038 | Function Loss:  -1.0538
# Total loss:  0.8416 | PDE Loss:  -0.4039 | Function Loss:  -1.0535
# Total loss:  0.8416 | PDE Loss:  -0.4039 | Function Loss:  -1.0511
# Total loss:  0.8415 | PDE Loss:  -0.404 | Function Loss:  -1.0484
# Total loss:  0.8414 | PDE Loss:  -0.4041 | Function Loss:  -1.044
# Total loss:  0.8414 | PDE Loss:  -0.4043 | Function Loss:  -1.041
# Total loss:  0.8413 | PDE Loss:  -0.4044 | Function Loss:  -1.0354
# Total loss:  0.8412 | PDE Loss:  -0.4046 | Function Loss:  -1.0337
# Total loss:  0.8412 | PDE Loss:  -0.4047 | Function Loss:  -1.0335
# Total loss:  0.8411 | PDE Loss:  -0.4048 | Function Loss:  -1.0336
# Total loss:  0.8411 | PDE Loss:  -0.4048 | Function Loss:  -1.0356
# Total loss:  0.8411 | PDE Loss:  -0.4049 | Function Loss:  -1.037
# Total loss:  0.8411 | PDE Loss:  -0.4048 | Function Loss:  -1.0419
# Total loss:  0.841 | PDE Loss:  -0.4048 | Function Loss:  -1.0445
# Total loss:  0.841 | PDE Loss:  -0.4048 | Function Loss:  -1.0463
# Total loss:  0.841 | PDE Loss:  -0.4048 | Function Loss:  -1.0484
# Total loss:  0.841 | PDE Loss:  -0.4048 | Function Loss:  -1.0492
# Total loss:  0.841 | PDE Loss:  -0.4048 | Function Loss:  -1.0496
# Total loss:  0.8409 | PDE Loss:  -0.4048 | Function Loss:  -1.0488
# Total loss:  0.8409 | PDE Loss:  -0.4048 | Function Loss:  -1.0472
# Total loss:  0.8409 | PDE Loss:  -0.4048 | Function Loss:  -1.0458
# Total loss:  0.8409 | PDE Loss:  -0.4049 | Function Loss:  -1.0427
# Total loss:  0.8409 | PDE Loss:  -0.4049 | Function Loss:  -1.0399
# Total loss:  0.8409 | PDE Loss:  -0.405 | Function Loss:  -1.035
# Total loss:  0.8408 | PDE Loss:  -0.4052 | Function Loss:  -1.0302
# Total loss:  0.8408 | PDE Loss:  -0.4054 | Function Loss:  -1.0194
# Total loss:  0.8407 | PDE Loss:  -0.4056 | Function Loss:  -1.0129
# Total loss:  0.8407 | PDE Loss:  -0.4058 | Function Loss:  -1.0061
# Total loss:  0.8406 | PDE Loss:  -0.4058 | Function Loss:  -1.0071
# Total loss:  0.8405 | PDE Loss:  -0.4058 | Function Loss:  -1.0112
# Total loss:  0.841 | PDE Loss:  -0.406 | Function Loss:  -0.9744
# Total loss:  0.8405 | PDE Loss:  -0.4059 | Function Loss:  -1.0117
# Total loss:  0.8404 | PDE Loss:  -0.4058 | Function Loss:  -1.0231
# Total loss:  0.8404 | PDE Loss:  -0.4057 | Function Loss:  -1.0277
# Total loss:  0.8403 | PDE Loss:  -0.4057 | Function Loss:  -1.0347
# Total loss:  0.8403 | PDE Loss:  -0.4057 | Function Loss:  -1.0362
# Total loss:  0.8402 | PDE Loss:  -0.4058 | Function Loss:  -1.0333
# Total loss:  0.8402 | PDE Loss:  -0.406 | Function Loss:  -1.0267
# Total loss:  0.8401 | PDE Loss:  -0.4061 | Function Loss:  -1.0233
# Total loss:  0.8401 | PDE Loss:  -0.4063 | Function Loss:  -1.0083
# Total loss:  0.8401 | PDE Loss:  -0.4065 | Function Loss:  -1.0033
# Total loss:  0.84 | PDE Loss:  -0.4066 | Function Loss:  -0.9965
# Total loss:  0.84 | PDE Loss:  -0.4068 | Function Loss:  -0.9892
# Total loss:  0.84 | PDE Loss:  -0.4069 | Function Loss:  -0.9796
# Total loss:  0.84 | PDE Loss:  -0.407 | Function Loss:  -0.9763
# Total loss:  0.84 | PDE Loss:  -0.4073 | Function Loss:  -0.963
# Total loss:  0.84 | PDE Loss:  -0.4072 | Function Loss:  -0.9699
# Total loss:  0.8399 | PDE Loss:  -0.4072 | Function Loss:  -0.9677
# Total loss:  0.8399 | PDE Loss:  -0.4073 | Function Loss:  -0.9679
# Total loss:  0.8399 | PDE Loss:  -0.4074 | Function Loss:  -0.9657
# Total loss:  0.8399 | PDE Loss:  -0.4074 | Function Loss:  -0.9634
# Total loss:  0.8398 | PDE Loss:  -0.4076 | Function Loss:  -0.9592
# Total loss:  0.8398 | PDE Loss:  -0.4078 | Function Loss:  -0.9537
# Total loss:  0.8414 | PDE Loss:  -0.4084 | Function Loss:  -0.8439
# Total loss:  0.8398 | PDE Loss:  -0.408 | Function Loss:  -0.9459
# Total loss:  0.8398 | PDE Loss:  -0.4079 | Function Loss:  -0.9495
# Total loss:  0.8397 | PDE Loss:  -0.408 | Function Loss:  -0.9461
# Total loss:  0.8397 | PDE Loss:  -0.4083 | Function Loss:  -0.9355
# Total loss:  0.8396 | PDE Loss:  -0.4084 | Function Loss:  -0.9325
# Total loss:  0.8398 | PDE Loss:  -0.4087 | Function Loss:  -0.9102
# Total loss:  0.8396 | PDE Loss:  -0.4085 | Function Loss:  -0.929
# Total loss:  0.8395 | PDE Loss:  -0.4086 | Function Loss:  -0.9261
# Total loss:  0.8395 | PDE Loss:  -0.4087 | Function Loss:  -0.9232
# Total loss:  0.8394 | PDE Loss:  -0.4088 | Function Loss:  -0.9209
# Total loss:  0.8402 | PDE Loss:  -0.4093 | Function Loss:  -0.861
# Total loss:  0.8394 | PDE Loss:  -0.409 | Function Loss:  -0.9151
# Total loss:  0.8393 | PDE Loss:  -0.409 | Function Loss:  -0.9172
# Total loss:  0.8392 | PDE Loss:  -0.4091 | Function Loss:  -0.9216
# Total loss:  0.8392 | PDE Loss:  -0.4093 | Function Loss:  -0.9182
# Total loss:  0.8391 | PDE Loss:  -0.4092 | Function Loss:  -0.9223
# Total loss:  0.8391 | PDE Loss:  -0.4093 | Function Loss:  -0.9255
# Total loss:  0.839 | PDE Loss:  -0.4093 | Function Loss:  -0.9283
# Total loss:  0.839 | PDE Loss:  -0.4094 | Function Loss:  -0.9299
# Total loss:  0.8389 | PDE Loss:  -0.4095 | Function Loss:  -0.9317
# Total loss:  0.8389 | PDE Loss:  -0.4095 | Function Loss:  -0.933
# Total loss:  0.8387 | PDE Loss:  -0.4096 | Function Loss:  -0.9355
# Total loss:  0.8386 | PDE Loss:  -0.4099 | Function Loss:  -0.931
# Total loss:  0.8385 | PDE Loss:  -0.4099 | Function Loss:  -0.9314
# Total loss:  0.8383 | PDE Loss:  -0.4101 | Function Loss:  -0.9321
# Total loss:  0.8382 | PDE Loss:  -0.4103 | Function Loss:  -0.9325
# Total loss:  0.838 | PDE Loss:  -0.4103 | Function Loss:  -0.9413
# Total loss:  0.8377 | PDE Loss:  -0.4105 | Function Loss:  -0.9452
# Total loss:  0.8374 | PDE Loss:  -0.4108 | Function Loss:  -0.9483
# Total loss:  0.8372 | PDE Loss:  -0.4111 | Function Loss:  -0.9468
# Total loss:  0.8371 | PDE Loss:  -0.4111 | Function Loss:  -0.9478
# Total loss:  0.8372 | PDE Loss:  -0.4114 | Function Loss:  -0.9284
# Total loss:  0.8371 | PDE Loss:  -0.4113 | Function Loss:  -0.9459
# Total loss:  0.837 | PDE Loss:  -0.4113 | Function Loss:  -0.9481
# Total loss:  0.8367 | PDE Loss:  -0.4114 | Function Loss:  -0.9614
# Total loss:  0.8366 | PDE Loss:  -0.4114 | Function Loss:  -0.9701
# Total loss:  0.8371 | PDE Loss:  -0.4116 | Function Loss:  -0.9219
# Total loss:  0.8363 | PDE Loss:  -0.4115 | Function Loss:  -0.9768
# Total loss:  0.8363 | PDE Loss:  -0.4115 | Function Loss:  -0.982
# Total loss:  0.8362 | PDE Loss:  -0.4115 | Function Loss:  -0.9866
# Total loss:  0.8361 | PDE Loss:  -0.4115 | Function Loss:  -0.9904
# Total loss:  0.8361 | PDE Loss:  -0.4116 | Function Loss:  -0.9935
# Total loss:  0.836 | PDE Loss:  -0.4116 | Function Loss:  -0.9969
# Total loss:  0.8359 | PDE Loss:  -0.4117 | Function Loss:  -1.0005
# Total loss:  0.8358 | PDE Loss:  -0.4117 | Function Loss:  -1.0016
# Total loss:  0.8358 | PDE Loss:  -0.4118 | Function Loss:  -1.0024
# Total loss:  0.8358 | PDE Loss:  -0.4118 | Function Loss:  -1.0006
# Total loss:  0.8357 | PDE Loss:  -0.4118 | Function Loss:  -0.9993
# Total loss:  0.8357 | PDE Loss:  -0.4119 | Function Loss:  -0.9964
# Total loss:  0.8357 | PDE Loss:  -0.412 | Function Loss:  -0.9929
# Total loss:  0.8356 | PDE Loss:  -0.412 | Function Loss:  -0.9898
# Total loss:  0.8417 | PDE Loss:  -0.4117 | Function Loss:  -0.7106
# Total loss:  0.8356 | PDE Loss:  -0.4121 | Function Loss:  -0.9895
# Total loss:  0.8356 | PDE Loss:  -0.4121 | Function Loss:  -0.9871
# Total loss:  0.8356 | PDE Loss:  -0.4122 | Function Loss:  -0.9853
# Total loss:  0.8355 | PDE Loss:  -0.4123 | Function Loss:  -0.984
# Total loss:  0.8355 | PDE Loss:  -0.4124 | Function Loss:  -0.9849
# Total loss:  0.8355 | PDE Loss:  -0.4124 | Function Loss:  -0.9835
# Total loss:  0.8354 | PDE Loss:  -0.4124 | Function Loss:  -0.9864
# Total loss:  0.8354 | PDE Loss:  -0.4124 | Function Loss:  -0.9884
# Total loss:  0.8354 | PDE Loss:  -0.4124 | Function Loss:  -0.9911
# Total loss:  0.8354 | PDE Loss:  -0.4124 | Function Loss:  -0.9942
# Total loss:  0.8353 | PDE Loss:  -0.4125 | Function Loss:  -0.9979
# Total loss:  0.8352 | PDE Loss:  -0.4125 | Function Loss:  -1.0005
# Total loss:  0.8351 | PDE Loss:  -0.4126 | Function Loss:  -1.0018
# Total loss:  0.835 | PDE Loss:  -0.4128 | Function Loss:  -0.9996
# Total loss:  0.8349 | PDE Loss:  -0.413 | Function Loss:  -0.9957
# Total loss:  0.8348 | PDE Loss:  -0.4132 | Function Loss:  -0.9882
# Total loss:  0.8362 | PDE Loss:  -0.4138 | Function Loss:  -0.8735
# Total loss:  0.8347 | PDE Loss:  -0.4133 | Function Loss:  -0.9833
# Total loss:  0.8347 | PDE Loss:  -0.4134 | Function Loss:  -0.9788
# Total loss:  0.8346 | PDE Loss:  -0.4135 | Function Loss:  -0.9796
# Total loss:  0.8346 | PDE Loss:  -0.4135 | Function Loss:  -0.9812
# Total loss:  0.8345 | PDE Loss:  -0.4136 | Function Loss:  -0.9831
# Total loss:  0.8345 | PDE Loss:  -0.4136 | Function Loss:  -0.9874
# Total loss:  0.8344 | PDE Loss:  -0.4137 | Function Loss:  -0.991
# Total loss:  0.8343 | PDE Loss:  -0.4137 | Function Loss:  -1.0018
# Total loss:  0.8342 | PDE Loss:  -0.4137 | Function Loss:  -1.0077
# Total loss:  0.8341 | PDE Loss:  -0.4137 | Function Loss:  -1.0171
# Total loss:  0.834 | PDE Loss:  -0.4138 | Function Loss:  -1.029
# Total loss:  0.8338 | PDE Loss:  -0.4138 | Function Loss:  -1.0417
# Total loss:  0.8336 | PDE Loss:  -0.4139 | Function Loss:  -1.0601
# Total loss:  0.8335 | PDE Loss:  -0.4139 | Function Loss:  -1.0738
# Total loss:  0.8333 | PDE Loss:  -0.414 | Function Loss:  -1.0905
# Total loss:  0.8333 | PDE Loss:  -0.4141 | Function Loss:  -1.0907
# Total loss:  0.8332 | PDE Loss:  -0.4141 | Function Loss:  -1.0965
# Total loss:  0.8332 | PDE Loss:  -0.4142 | Function Loss:  -1.0973
# Total loss:  0.8329 | PDE Loss:  -0.4142 | Function Loss:  -1.1169
# Total loss:  0.8329 | PDE Loss:  -0.4145 | Function Loss:  -1.1133
# Total loss:  0.8327 | PDE Loss:  -0.4144 | Function Loss:  -1.1322
# Total loss:  0.8326 | PDE Loss:  -0.4144 | Function Loss:  -1.1417
# Total loss:  0.8325 | PDE Loss:  -0.4144 | Function Loss:  -1.1422
# Total loss:  0.8324 | PDE Loss:  -0.4145 | Function Loss:  -1.1437
# Total loss:  0.8324 | PDE Loss:  -0.4146 | Function Loss:  -1.1473
# Total loss:  0.8323 | PDE Loss:  -0.4147 | Function Loss:  -1.1533
# Total loss:  0.8322 | PDE Loss:  -0.4148 | Function Loss:  -1.1651
# Total loss:  0.8321 | PDE Loss:  -0.4148 | Function Loss:  -1.1763
# Total loss:  0.832 | PDE Loss:  -0.4149 | Function Loss:  -1.1902
# Total loss:  0.832 | PDE Loss:  -0.4149 | Function Loss:  -1.198
# Total loss:  0.832 | PDE Loss:  -0.4149 | Function Loss:  -1.2019
# Total loss:  0.8319 | PDE Loss:  -0.4149 | Function Loss:  -1.204
# Total loss:  0.8319 | PDE Loss:  -0.4149 | Function Loss:  -1.2038
# Total loss:  0.8319 | PDE Loss:  -0.415 | Function Loss:  -1.2019
# Total loss:  0.8319 | PDE Loss:  -0.415 | Function Loss:  -1.1997
# Total loss:  0.8319 | PDE Loss:  -0.415 | Function Loss:  -1.1973
# Total loss:  0.8319 | PDE Loss:  -0.415 | Function Loss:  -1.1933
# Total loss:  0.8318 | PDE Loss:  -0.4151 | Function Loss:  -1.191
# Total loss:  0.8318 | PDE Loss:  -0.4151 | Function Loss:  -1.1909
# Total loss:  0.8318 | PDE Loss:  -0.4151 | Function Loss:  -1.1926
# Total loss:  0.8317 | PDE Loss:  -0.415 | Function Loss:  -1.1961
# Total loss:  0.8317 | PDE Loss:  -0.415 | Function Loss:  -1.1971
# Total loss:  0.8317 | PDE Loss:  -0.4151 | Function Loss:  -1.2017
# Total loss:  0.8317 | PDE Loss:  -0.4151 | Function Loss:  -1.2046
# Total loss:  0.8316 | PDE Loss:  -0.4151 | Function Loss:  -1.2066
# Total loss:  0.8316 | PDE Loss:  -0.4152 | Function Loss:  -1.2081
# Total loss:  0.8316 | PDE Loss:  -0.4152 | Function Loss:  -1.2088
# Total loss:  0.8315 | PDE Loss:  -0.4152 | Function Loss:  -1.2079
# Total loss:  0.8315 | PDE Loss:  -0.4153 | Function Loss:  -1.2015
# Total loss:  0.8313 | PDE Loss:  -0.4155 | Function Loss:  -1.1878
# Total loss:  0.8312 | PDE Loss:  -0.4155 | Function Loss:  -1.185
# Total loss:  0.831 | PDE Loss:  -0.4157 | Function Loss:  -1.18
# Total loss:  0.8331 | PDE Loss:  -0.4161 | Function Loss:  -0.9723
# Total loss:  0.831 | PDE Loss:  -0.4158 | Function Loss:  -1.1689
# Total loss:  0.8311 | PDE Loss:  -0.416 | Function Loss:  -1.1294
# Total loss:  0.8309 | PDE Loss:  -0.4159 | Function Loss:  -1.1648
# Total loss:  0.8309 | PDE Loss:  -0.4159 | Function Loss:  -1.1667
# Total loss:  0.8308 | PDE Loss:  -0.416 | Function Loss:  -1.1655
# Total loss:  0.8308 | PDE Loss:  -0.4161 | Function Loss:  -1.1593
# Total loss:  0.8307 | PDE Loss:  -0.4161 | Function Loss:  -1.1555
# Total loss:  0.8307 | PDE Loss:  -0.4163 | Function Loss:  -1.1431
# Total loss:  0.8306 | PDE Loss:  -0.4164 | Function Loss:  -1.1321
# Total loss:  0.8305 | PDE Loss:  -0.4166 | Function Loss:  -1.1194
# Total loss:  0.8304 | PDE Loss:  -0.4166 | Function Loss:  -1.111
# Total loss:  0.8304 | PDE Loss:  -0.4167 | Function Loss:  -1.1068
# Total loss:  0.8303 | PDE Loss:  -0.4167 | Function Loss:  -1.1044
# Total loss:  0.8303 | PDE Loss:  -0.4168 | Function Loss:  -1.1065
# Total loss:  0.8301 | PDE Loss:  -0.417 | Function Loss:  -1.1029
# Total loss:  0.83 | PDE Loss:  -0.4172 | Function Loss:  -1.1036
# Total loss:  0.83 | PDE Loss:  -0.4174 | Function Loss:  -1.0883
# Total loss:  0.8299 | PDE Loss:  -0.4174 | Function Loss:  -1.0904
# Total loss:  0.8298 | PDE Loss:  -0.4175 | Function Loss:  -1.0919
# Total loss:  0.8298 | PDE Loss:  -0.4176 | Function Loss:  -1.0872
# Total loss:  0.8297 | PDE Loss:  -0.4178 | Function Loss:  -1.0797
# Total loss:  0.8297 | PDE Loss:  -0.4178 | Function Loss:  -1.0789
# Total loss:  0.8296 | PDE Loss:  -0.4178 | Function Loss:  -1.0767
# Total loss:  0.8296 | PDE Loss:  -0.4178 | Function Loss:  -1.074
# Total loss:  0.8296 | PDE Loss:  -0.4178 | Function Loss:  -1.0723
# Total loss:  0.8296 | PDE Loss:  -0.4179 | Function Loss:  -1.0695
# Total loss:  0.8296 | PDE Loss:  -0.4179 | Function Loss:  -1.0668
# Total loss:  0.8296 | PDE Loss:  -0.4179 | Function Loss:  -1.0632
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0614
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0595
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.058
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0597
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.059
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0594
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0596
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0597
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0577
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0589
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0595
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0594
# Total loss:  0.8296 | PDE Loss:  -0.418 | Function Loss:  -1.0597
# Final Loss:  0.8295795321464539

# %%
pinn.plotting()
